# %%
import os
import torch
from torch.utils.data import Dataset
from PIL import Image
from torchvision import transforms
import cv2
import torch.nn as nn
from torch.utils.data import DataLoader
import torch.nn.functional as F
import torch.optim as optim
from torch.nn.utils.rnn import pad_sequence
import numpy as np

# %%
def preprocess(image_path):
    img = cv2.imread(image_path)
    
    mask = np.all(img == [0, 0, 0], axis=-1)
    img[mask] = [255, 255, 255]
    
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    binary = cv2.adaptiveThreshold(
        gray, 255,
        cv2.ADAPTIVE_THRESH_MEAN_C,
        cv2.THRESH_BINARY,
        blockSize=15,
        C=3
    )
    
    x, y, w, h = cv2.boundingRect(cv2.findNonZero(cv2.bitwise_not(binary)))
    return img[y:y+h, x:x+w]

# %%
class CaptchaDataset(Dataset):
    def __init__(self, folder_path, vocab):
        self.folder_path = folder_path
        self.image_files = os.listdir(folder_path)
        self.vocab = vocab
        self.char_to_idx = {c: i + 1 for i, c in enumerate(vocab)}  # 0 is CTC blank
        self.idx_to_char = {i + 1: c for i, c in enumerate(vocab)}

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        filename = self.image_files[idx]
        label_str = filename.split("-")[0]
        label = torch.tensor([self.char_to_idx[c] for c in label_str], dtype=torch.long)        

        image_path = os.path.join(self.folder_path, filename)
        image = preprocess(image_path)
        
        image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        # Resize to model input size
        image = cv2.resize(image, (200, 50))  # (W, H)

        # Optional normalization
        image = image.astype("float32")
        image /= 255.0  # Normalize to [0, 1]

        # Convert to tensor with shape (1, H, W)
        image = torch.from_numpy(image).unsqueeze(0)  # shape: (1, 50, 200)
        
        return image, label, len(label)

# %% [markdown]
# # Basic model from scratch

# %%
class CNNLSTMCTC(nn.Module):
    def __init__(self, vocab_size):
        super().__init__()
        self.cnn = nn.Sequential(
            nn.Conv2d(1, 32, 3, padding=1),  # -> (32, 50, 200)
            nn.ReLU(),
            nn.MaxPool2d(2, 2),              # -> (32, 25, 100)
            nn.Conv2d(32, 64, 3, padding=1), # -> (64, 25, 100)
            nn.ReLU(),
            nn.MaxPool2d(2, 2),              # -> (64, 12, 50)
        )
        self.lstm = nn.LSTM(input_size=64*12, hidden_size=128, num_layers=2, bidirectional=True)
        self.fc = nn.Linear(128 * 2, vocab_size + 1)  # +1 for blank

    def forward(self, x):
        x = self.cnn(x)  # (B, C, H, W)
        b, c, h, w = x.size()
        x = x.permute(3, 0, 1, 2).contiguous()  # (W, B, C, H)
        x = x.view(w, b, c * h)  # (T, B, input_size)
        x, _ = self.lstm(x)      # (T, B, 256)
        x = self.fc(x)           # (T, B, vocab+1)
        return x

# %%
def collate_fn(batch):
    images, labels, label_lengths = zip(*batch)
    images = torch.stack(images)
    labels = torch.cat(labels)
    label_lengths = torch.tensor(label_lengths, dtype=torch.long)

    return images, labels, label_lengths


def train(model, dataloader, optimizer, criterion, device):
    model.train()
    total_loss = 0
    num_batches = 0
    
    for images, labels, label_lengths in dataloader:
        images = images.to(device)
        labels = labels.to(device)
        label_lengths = label_lengths.to(device)

        logits = model(images)  # (T, B, C)
        input_lengths = torch.full(size=(images.size(0),), fill_value=logits.size(0), dtype=torch.long).to(device)

        log_probs = F.log_softmax(logits, dim=2)
        loss = criterion(log_probs, labels, input_lengths, label_lengths)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
        num_batches += 1

    avg_loss = total_loss / num_batches
    print(f"Average Epoch Loss: {avg_loss:.4f}")

# %%
def greedy_decoder(logits, idx_to_char):
    pred = torch.argmax(logits, dim=2)  # (T, B)
    pred = pred.permute(1, 0)  # (B, T)

    results = []
    for p in pred:
        seq = []
        prev = -1
        for char_idx in p:
            if char_idx.item() != prev and char_idx.item() != 0:
                seq.append(idx_to_char[char_idx.item()])
            prev = char_idx.item()
        results.append("".join(seq))
    return results

# %%
vocab = "abcdefghijklmnopqrstuvwxyz0123456789"

# %%
# Dataset & DataLoader
dataset = CaptchaDataset("train", vocab)
dataloader = DataLoader(dataset, batch_size=16, shuffle=True, collate_fn=collate_fn)

# Model, Optimizer, Loss
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = CNNLSTMCTC(vocab_size=len(vocab)).to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.CTCLoss(blank=0, zero_infinity=True)

checkpoint_path = "image_input_scratch.pt"
if os.path.exists(checkpoint_path):
    model.load_state_dict(torch.load(checkpoint_path, map_location=device))
    print("✅ Loaded pretrained model from", checkpoint_path)
else:
    print("🚀 No checkpoint found, training from scratch")
    for epoch in range(10):
        print(f"\nEpoch {epoch+1}")
        train(model, dataloader, optimizer, criterion, device)
    torch.save(model.state_dict(), checkpoint_path)
# Out:
# 🚀 No checkpoint found, training from scratch
#
# Epoch 1
# Average Epoch Loss: 4.1389
#
# Epoch 2
# Average Epoch Loss: 3.9185
#
# Epoch 3
# Average Epoch Loss: 3.8611
#
# Epoch 4
# Average Epoch Loss: 3.0780
#
# Epoch 5
# Average Epoch Loss: 1.9143
#
# Epoch 6
# Average Epoch Loss: 1.3952
#
# Epoch 7
# Average Epoch Loss: 1.1443
#
# Epoch 8
# Average Epoch Loss: 0.9731
#
# Epoch 9
# Average Epoch Loss: 0.8385
#
# Epoch 10
# Average Epoch Loss: 0.7386

# %% [markdown]
# ## Result
# Word Accuracy: 28.00%
# Character Accuracy: 70.67%

# %%
test_dataset = CaptchaDataset("test", vocab)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False, collate_fn=collate_fn)

# %%
model.eval()

total_words = 0
correct_words = 0

total_chars = 0
correct_chars = 0

with torch.no_grad():
    for images, labels, label_lengths in test_loader:
        images = images.to(device)
        logits = model(images)  # (T, B, C)
        predictions = greedy_decoder(logits.cpu(), test_dataset.idx_to_char)

        for i in range(len(predictions)):
            true_label = "".join([test_dataset.idx_to_char[idx.item()] for idx in labels])
            pred_label = predictions[i]

            total_words += 1
            if pred_label == true_label:
                correct_words += 1

            char_matches = sum(1 for a, b in zip(true_label, pred_label) if a == b)
            correct_chars += char_matches
            total_chars += len(true_label)

            print(f"True: {true_label.ljust(10)} | Pred: {pred_label.ljust(10)} | Char Acc: {char_matches}/{len(true_label)}")

word_acc = correct_words / total_words * 100
char_acc = correct_chars / total_chars * 100
print(f"Word Accuracy: {word_acc:.2f}%")
print(f"Character Accuracy: {char_acc:.2f}%")
# Out:
# True: 002e23     | Pred: 002e23     | Char Acc: 6/6
# True: 03yl9s     | Pred: d3yi9s     | Char Acc: 4/6
# True: 03yuav5    | Pred: 03yuqv5    | Char Acc: 6/7
# True: 03zl9o     | Pred: 03zl90     | Char Acc: 5/6
# True: 04zqohgi   | Pred: 04zqoh9i   | Char Acc: 7/8
# True: 05htm      | Pred: 05htm      | Char Acc: 5/5
# True: 05pb       | Pred: 03pb       | Char Acc: 3/4
# True: 07oj       | Pred: 070j       | Char Acc: 3/4
# True: 07z0       | Pred: 07z0       | Char Acc: 4/4
# True: 08ft2e2z   | Pred: 08i12e22   | Char Acc: 5/8
# True: 08nxd77    | Pred: 08nxd77    | Char Acc: 7/7
# True: 08otejfi   | Pred: 080tejfz   | Char Acc: 6/8
# True: 08sba      | Pred: 08sba      | Char Acc: 5/5
# True: 09popm     | Pred: 09popm     | Char Acc: 6/6
# True: 0a7sh2wp   | Pred: qc7jh2np   | Char Acc: 4/8
# True: 0al4pl     | Pred: 0al49l     | Char Acc: 5/6
# True: 0c3dp      | Pred: 0c3dp      | Char Acc: 5/5
# True: 0c7mgdmd   | Pred: 007m9dmd   | Char Acc: 6/8
# True: 0chnm34    | Pred: 048nm34    | Char Acc: 5/7
# True: 0col7w     | Pred: qc0l7w     | Char Acc: 4/6
# True: 0cr6       | Pred: 0gx5       | Char Acc: 1/4
# True: 0dx9       | Pred: 0dx9       | Char Acc: 4/4
# True: 0fa6qtkn   | Pred: 0fa8qlkn   | Char Acc: 6/8
# True: 0favtnx    | Pred: ofavtxx    | Char Acc: 5/7
# True: 0fee       | Pred: 0foo       | Char Acc: 2/4
# True: 0gil       | Pred: 0gi1       | Char Acc: 3/4
# True: 0gzwaq8    | Pred: 0ezwaow    | Char Acc: 4/7
# True: 0h5ya8     | Pred: qh5ya8     | Char Acc: 5/6
# True: 0i7uom     | Pred: 9i7uom     | Char Acc: 5/6
# True: 0ilhsr2t   | Pred: lxuhgr21   | Char Acc: 3/8
# True: 0iqk95h    | Pred: 0iqk95h    | Char Acc: 7/7
# True: 0k2lyyc    | Pred: 0kzyyc     | Char Acc: 3/7
# True: 0lfjfob    | Pred: dug        | Char Acc: 0/7
# True: 0me2a      | Pred: 0me2a      | Char Acc: 5/5
# True: 0mgnhi     | Pred: 0mgwh1     | Char Acc: 4/6
# True: 0msi       | Pred: 0wsi       | Char Acc: 3/4
# True: 0n5546     | Pred: 0n5546     | Char Acc: 6/6
# True: 0nq0e      | Pred: 0n80e      | Char Acc: 4/5
# True: 0nucs59    | Pred: 0nucs59    | Char Acc: 7/7
# True: 0pglswc    | Pred: 0pglswc    | Char Acc: 7/7
# True: 0pv2w1t    | Pred: 0pvzw1t    | Char Acc: 6/7
# True: 0qtjdlvt   | Pred: 0gtjqlut   | Char Acc: 5/8
# True: 0rlbarm    | Pred: 0rl8aam    | Char Acc: 5/7
# True: 0rq9qn     | Pred: 0fq9qq     | Char Acc: 4/6
# True: 0rw4sjk    | Pred: 9pw4s3k    | Char Acc: 4/7
# True: 0s2rn2o    | Pred: 052hne0    | Char Acc: 3/7
# True: 0scs       | Pred: 0sc5       | Char Acc: 3/4
# True: 0sia       | Pred: d5ra       | Char Acc: 1/4
# True: 0sm8cb4c   | Pred: 0sm8cbfc   | Char Acc: 7/8
# True: 0tbe       | Pred: 0the       | Char Acc: 3/4
# True: 0u0y5      | Pred: didd9      | Char Acc: 0/5
# True: 0u4aj      | Pred: 0u4aj      | Char Acc: 5/5
# True: 0v4o0p     | Pred: 0dxu0p     | Char Acc: 3/6
# True: 0vug13     | Pred: 0vugj3     | Char Acc: 5/6
# True: 0w0pankd   | Pred: 0w0papkd   | Char Acc: 7/8
# True: 0wcz1w     | Pred: 0wcz1w     | Char Acc: 6/6
# True: 0wla       | Pred: gsls       | Char Acc: 1/4
# True: 0wy4otel   | Pred: 0wy4otei   | Char Acc: 7/8
# True: 0yoxyw5    | Pred: 0y0xyw6    | Char Acc: 5/7
# True: 11nm       | Pred: 11nm       | Char Acc: 4/4
# True: 1324mrg    | Pred: 1324mrc    | Char Acc: 6/7
# True: 13be3kf    | Pred: 13ee3kf    | Char Acc: 6/7
# True: 13bsgn2    | Pred: 13bsqn2    | Char Acc: 6/7
# True: 13v4msh    | Pred: 13v4msh    | Char Acc: 7/7
# True: 13xy       | Pred: i3xy       | Char Acc: 3/4
# True: 153tt0     | Pred: g3ri0      | Char Acc: 0/6
# True: 17z8030    | Pred: 17z8030    | Char Acc: 7/7
# True: 18gg       | Pred: 18qq       | Char Acc: 2/4
# True: 19hz       | Pred: 19hz       | Char Acc: 4/4
# True: 1asdyrv    | Pred: 1asdyrv    | Char Acc: 7/7
# True: 1avc       | Pred: 1avc       | Char Acc: 4/4
# True: 1awqu      | Pred: jawqu      | Char Acc: 4/5
# True: 1bu55hc    | Pred: 1bu5swo    | Char Acc: 4/7
# True: 1c3bi3zm   | Pred: ll38134m   | Char Acc: 3/8
# True: 1cfa40wy   | Pred: 4cfoh0wy   | Char Acc: 5/8
# True: 1ctc5l     | Pred: 1ctql      | Char Acc: 3/6
# True: 1dhcacd    | Pred: 1dhcacd    | Char Acc: 7/7
# True: 1dy0p      | Pred: 1o49p      | Char Acc: 2/5
# True: 1e1qxwyz   | Pred: 2e2qkwy    | Char Acc: 4/8
# True: 1ed0i9xz   | Pred: 18d0i9xz   | Char Acc: 7/8
# True: 1ewgub4    | Pred: 1ewgued    | Char Acc: 5/7
# True: 1ewq       | Pred: 1ew0       | Char Acc: 3/4
# True: 1fh4thm    | Pred: ifh4bhm    | Char Acc: 5/7
# True: 1gbu5qus   | Pred: 1gbu5qug   | Char Acc: 7/8
# True: 1ghx0spj   | Pred: ighx0spj   | Char Acc: 7/8
# True: 1hiqbpx3   | Pred: hiqbpxs    | Char Acc: 0/8
# True: 1imwt      | Pred: 1imwe      | Char Acc: 4/5
# True: 1irn       | Pred: 1ian       | Char Acc: 3/4
# True: 1iwe       | Pred: iiwe       | Char Acc: 3/4
# True: 1j2xhu     | Pred: 7j2xwu     | Char Acc: 4/6
# True: 1k94       | Pred: 1494       | Char Acc: 3/4
# True: 1kfm       | Pred: 1hfm       | Char Acc: 3/4
# True: 1ku9bzoy   | Pred: 1ku9bzoy   | Char Acc: 8/8
# True: 1mrffz     | Pred: 1mrqfz     | Char Acc: 5/6
# True: 1mwa       | Pred: 1mwa       | Char Acc: 4/4
# True: 1nyd       | Pred: inyd       | Char Acc: 3/4
# True: 1o5kcof    | Pred: lo5kcof    | Char Acc: 6/7
# True: 1ozltu     | Pred: xocltu     | Char Acc: 4/6
# True: 1qp4885m   | Pred: 1qp4866m   | Char Acc: 6/8
# True: 1rhud8rx   | Pred: 1rvd8rx    | Char Acc: 2/8
# True: 1sil9      | Pred: 1s1lq      | Char Acc: 3/5
# True: 1tyn       | Pred: 1fya       | Char Acc: 2/4
# True: 1u81r      | Pred: ig8ia      | Char Acc: 1/5
# True: 1ulul      | Pred: 7u1u1      | Char Acc: 2/5
# True: 1wu0cul    | Pred: 1wue2gl    | Char Acc: 4/7
# True: 1x44n7nx   | Pred: q14493vp   | Char Acc: 2/8
# True: 1x8ljpi    | Pred: qa8djpc    | Char Acc: 3/7
# True: 1xut0w4    | Pred: lxut0w1    | Char Acc: 5/7
# True: 1zcg2o     | Pred: zcgo       | Char Acc: 0/6
# True: 20ka8wmo   | Pred: 20ka8wnd   | Char Acc: 6/8
# True: 21iyxsn    | Pred: zii4h5n    | Char Acc: 2/7
# True: 21z1y      | Pred: 2iziy      | Char Acc: 3/5
# True: 220ofgki   | Pred: p28ofgki   | Char Acc: 6/8
# True: 23osam     | Pred: 23osam     | Char Acc: 6/6
# True: 24idbq3f   | Pred: 241dbq3f   | Char Acc: 7/8
# True: 24y0s85    | Pred: 24yq585    | Char Acc: 5/7
# True: 265qfy     | Pred: 265qfy     | Char Acc: 6/6
# True: 26pw3      | Pred: 26pw3      | Char Acc: 5/5
# True: 273u       | Pred: 273u       | Char Acc: 4/4
# True: 27hibrae   | Pred: a7ki8rac   | Char Acc: 4/8
# True: 29bgk      | Pred: 29bgk      | Char Acc: 5/5
# True: 29or       | Pred: 2mor       | Char Acc: 3/4
# True: 2aidl      | Pred: 2a1d1      | Char Acc: 3/5
# True: 2bdh       | Pred: 2bdh       | Char Acc: 4/4
# True: 2bjj1pos   | Pred: 2bj21pos   | Char Acc: 7/8
# True: 2c5ol      | Pred: 2c5of      | Char Acc: 4/5
# True: 2cteaog    | Pred: 2cteaog    | Char Acc: 7/7
# True: 2d0qj      | Pred: 2dqqj      | Char Acc: 4/5
# True: 2d76       | Pred: 2d76       | Char Acc: 4/4
# True: 2ennujkj   | Pred: 2enaujhj   | Char Acc: 6/8
# True: 2flvu7n    | Pred: zfico7i    | Char Acc: 2/7
# True: 2fxu0s     | Pred: 2fxu0s     | Char Acc: 6/6
# True: 2fyohm     | Pred: 2f3o4m     | Char Acc: 4/6
# True: 2gbiw7     | Pred: 2geiw7     | Char Acc: 5/6
# True: 2gquin1i   | Pred: 2gquinii   | Char Acc: 7/8
# True: 2gslhci    | Pred: 2aglhc1    | Char Acc: 4/7
# True: 2iulzl     | Pred: 2iulzl     | Char Acc: 6/6
# True: 2k1xlp     | Pred: 2k1xlp     | Char Acc: 6/6
# True: 2m1qu1e4   | Pred: 2m1qu1ew   | Char Acc: 7/8
# True: 2mo9qj39   | Pred: 2mo9qj39   | Char Acc: 8/8
# True: 2mvjsa     | Pred: 2mvjsa     | Char Acc: 6/6
# True: 2n2it3lx   | Pred: 2n2it3lk   | Char Acc: 7/8
# True: 2njlt4     | Pred: 2njit4     | Char Acc: 5/6
# True: 2o6f       | Pred: 206f       | Char Acc: 3/4
# True: 2oa73      | Pred: 2oo73      | Char Acc: 4/5
# True: 2oy2f9     | Pred: qqy2f9     | Char Acc: 4/6
# True: 2p6wwybk   | Pred: 2p8wwyh    | Char Acc: 5/8
# True: 2q9zjsun   | Pred: 2zjsun     | Char Acc: 1/8
# True: 2qhqtv2    | Pred: 2phqtv2    | Char Acc: 6/7
# True: 2rs4jvyr   | Pred: 2r59duy6   | Char Acc: 3/8
# True: 2sp9gvbi   | Pred: 2sp9gy8l   | Char Acc: 5/8
# True: 2sxkz2vj   | Pred: 2sxkz2ui   | Char Acc: 6/8
# True: 2t02x      | Pred: 2102x      | Char Acc: 4/5
# True: 2txh8      | Pred: 2txha      | Char Acc: 4/5
# True: 2tyw3      | Pred: 2tyw3      | Char Acc: 5/5
# True: 2u6t6      | Pred: 2u6tb      | Char Acc: 4/5
# True: 2v2n13je   | Pred: 2v2n13je   | Char Acc: 8/8
# True: 2vapwy     | Pred: 2vapwy     | Char Acc: 6/6
# True: 2w02hmo    | Pred: 2w02hmg    | Char Acc: 6/7
# True: 2x7qps0    | Pred: 4xfqps0    | Char Acc: 5/7
# True: 2y11w      | Pred: 2y1zw      | Char Acc: 4/5
# True: 2y43vf     | Pred: 2y1auf     | Char Acc: 3/6
# True: 2ybig03    | Pred: 2ybig03    | Char Acc: 7/7
# True: 2yjiz      | Pred: 2yui2      | Char Acc: 3/5
# True: 2yjoie     | Pred: lyj0ie     | Char Acc: 4/6
# True: 2yqdk      | Pred: 2yqok      | Char Acc: 4/5
# True: 2zkfhs1n   | Pred: 2zhfh5ip   | Char Acc: 4/8
# True: 2zs3       | Pred: 2z53       | Char Acc: 3/4
# True: 30rju0c    | Pred: 30rju0c    | Char Acc: 7/7
# True: 30znefk    | Pred: 30zpafk    | Char Acc: 5/7
# True: 31qyiq     | Pred: 31qyiq     | Char Acc: 6/6
# True: 327gm      | Pred: 327gm      | Char Acc: 5/5
# True: 32evcjk8   | Pred: sjz9gjy3   | Char Acc: 1/8
# True: 32llr      | Pred: 32iir      | Char Acc: 3/5
# True: 33yxl      | Pred: xxjxx      | Char Acc: 1/5
# True: 345ar      | Pred: 345ar      | Char Acc: 5/5
# True: 35av6      | Pred: 35av6      | Char Acc: 5/5
# True: 36ev8oj    | Pred: 36ez8o1    | Char Acc: 5/7
# True: 379cfumx   | Pred: 379cfunx   | Char Acc: 7/8
# True: 386h7      | Pred: 786h5      | Char Acc: 3/5
# True: 38v2mv     | Pred: 3j9jw9     | Char Acc: 1/6
# True: 39fyn9     | Pred: 39fyn9     | Char Acc: 6/6
# True: 39uww47    | Pred: 99uww47    | Char Acc: 6/7
# True: 3aa8       | Pred: 3ao8       | Char Acc: 3/4
# True: 3aut4      | Pred: 3aut4      | Char Acc: 5/5
# True: 3b84c7sq   | Pred: 9984q7iq   | Char Acc: 4/8
# True: 3easf      | Pred: 8ecsf      | Char Acc: 3/5
# True: 3eo06      | Pred: 3gdqg      | Char Acc: 1/5
# True: 3eyys      | Pred: 3eyys      | Char Acc: 5/5
# True: 3flp3ljj   | Pred: 7iz3ze     | Char Acc: 0/8
# True: 3fv5o      | Pred: gfygd      | Char Acc: 1/5
# True: 3g34h      | Pred: 3g34h      | Char Acc: 5/5
# True: 3g79jlr    | Pred: 3g79jlr    | Char Acc: 7/7
# True: 3ho9       | Pred: 3xd3       | Char Acc: 1/4
# True: 3ia0oel    | Pred: 33o00e1    | Char Acc: 3/7
# True: 3ido1q0    | Pred: 3ido1q0    | Char Acc: 7/7
# True: 3ii4       | Pred: 3iay       | Char Acc: 2/4
# True: 3j61hli    | Pred: 3j81nle    | Char Acc: 4/7
# True: 3lsrj      | Pred: 3srj       | Char Acc: 1/5
# True: 3ltl6jon   | Pred: 3ltl6j0h   | Char Acc: 6/8
# True: 3m22       | Pred: 3m22       | Char Acc: 4/4
# True: 3mlhaz     | Pred: 3mhm       | Char Acc: 2/6
# True: 3mtklt8z   | Pred: 3mthjt8z   | Char Acc: 6/8
# True: 3n6o       | Pred: 3n60       | Char Acc: 3/4
# True: 3nnz7pka   | Pred: 3hac3qwa   | Char Acc: 2/8
# True: 3nw0pr     | Pred: 3cwdpr     | Char Acc: 4/6
# True: 3ov5w      | Pred: 3ovsw      | Char Acc: 4/5
# True: 3psc       | Pred: 3psc       | Char Acc: 4/4
# True: 3q9kl33x   | Pred: 3q9kl33x   | Char Acc: 8/8
# True: 3r677      | Pred: 3r677      | Char Acc: 5/5
# True: 3s10de     | Pred: 3sl0de     | Char Acc: 5/6
# True: 3sfzj      | Pred: 35f23      | Char Acc: 2/5
# True: 3smh1i     | Pred: 39mhi1     | Char Acc: 3/6
# True: 3v02       | Pred: 3v02       | Char Acc: 4/4
# True: 3v1p       | Pred: 3v1p       | Char Acc: 4/4
# True: 3vslm      | Pred: 3vslm      | Char Acc: 5/5
# True: 3w4cxb4    | Pred: 3w4cxb4    | Char Acc: 7/7
# True: 3wif       | Pred: s3w7       | Char Acc: 0/4
# True: 3wpp       | Pred: 3wpp       | Char Acc: 4/4
# True: 3y9sdh     | Pred: 3y9edh     | Char Acc: 5/6
# True: 3ymdwwi    | Pred: 3ymowwi    | Char Acc: 6/7
# True: 3yyklwn    | Pred: 344klmn    | Char Acc: 4/7
# True: 3za8zi     | Pred: 3za9zi     | Char Acc: 5/6
# True: 40q5v7l2   | Pred: 40q5v7i2   | Char Acc: 7/8
# True: 41kb       | Pred: 4jh8       | Char Acc: 1/4
# True: 42fs       | Pred: 42fs       | Char Acc: 4/4
# True: 42g6nr0    | Pred: 42ggp9o    | Char Acc: 3/7
# True: 438j245    | Pred: v32i245    | Char Acc: 4/7
# True: 43uquhed   | Pred: 43uquhed   | Char Acc: 8/8
# True: 45weu      | Pred: sgjru      | Char Acc: 1/5
# True: 47v30      | Pred: g3uqg      | Char Acc: 0/5
# True: 48nd6j     | Pred: 48no6j     | Char Acc: 5/6
# True: 48qgg4t    | Pred: a80gg47    | Char Acc: 4/7
# True: 4943m      | Pred: 4943m      | Char Acc: 5/5
# True: 49uqb      | Pred: 49y33      | Char Acc: 2/5
# True: 4azbsnf4   | Pred: n4i6smf4   | Char Acc: 3/8
# True: 4b3eze4x   | Pred: td3ezc1a   | Char Acc: 3/8
# True: 4bsoa      | Pred: 46s0a      | Char Acc: 3/5
# True: 4bvb5      | Pred: 4bvb5      | Char Acc: 5/5
# True: 4bzcur8r   | Pred: 48zcur8r   | Char Acc: 7/8
# True: 4cjt       | Pred: 4cjt       | Char Acc: 4/4
# True: 4cyx       | Pred: ycyx       | Char Acc: 3/4
# True: 4d6ddrc    | Pred: 4d6ddrc    | Char Acc: 7/7
# True: 4dbe       | Pred: 4q4e       | Char Acc: 2/4
# True: 4drah      | Pred: qrqh       | Char Acc: 0/5
# True: 4dxxn2     | Pred: 4dxxn2     | Char Acc: 6/6
# True: 4dzwx      | Pred: 7qzkx      | Char Acc: 2/5
# True: 4eb0ys     | Pred: 4e50ys     | Char Acc: 5/6
# True: 4edetz3    | Pred: 4edetz3    | Char Acc: 7/7
# True: 4esp       | Pred: 4e1p       | Char Acc: 3/4
# True: 4eyb0      | Pred: 0eya0      | Char Acc: 3/5
# True: 4fxwgg4    | Pred: 4fxwgg4    | Char Acc: 7/7
# True: 4g453z3p   | Pred: 4g4s3z3p   | Char Acc: 7/8
# True: 4gbj3dq    | Pred: 4ybj3qq    | Char Acc: 5/7
# True: 4ggz8z     | Pred: 4gyz8x     | Char Acc: 4/6
# True: 4hdb       | Pred: 4kjb       | Char Acc: 2/4
# True: 4hjvpr     | Pred: 4hjvpr     | Char Acc: 6/6
# True: 4howdgcj   | Pred: 4honpgcj   | Char Acc: 6/8
# True: 4hqru      | Pred: 4hqru      | Char Acc: 5/5
# True: 4hty698    | Pred: 4ht4698    | Char Acc: 6/7
# True: 4hycg      | Pred: 4hvcg      | Char Acc: 4/5
# True: 4ina3nwq   | Pred: 4inc3nwg   | Char Acc: 6/8
# True: 4jyag      | Pred: ksyhq      | Char Acc: 1/5
# True: 4khjkei    | Pred: 4khjke6    | Char Acc: 6/7
# True: 4kw6xv     | Pred: 4kw6xv     | Char Acc: 6/6
# True: 4lg11      | Pred: 4lg11      | Char Acc: 5/5
# True: 4ll943lc   | Pred: y19x3lc    | Char Acc: 0/8
# True: 4mby0ex    | Pred: 4mdy0ea    | Char Acc: 5/7
# True: 4n3bk      | Pred: y27hj      | Char Acc: 0/5
# True: 4n6z       | Pred: 4n6z       | Char Acc: 4/4
# True: 4ni1kw     | Pred: 4at1kv     | Char Acc: 3/6
# True: 4nt8w      | Pred: 4nt8w      | Char Acc: 5/5
# True: 4o2pd      | Pred: 4o2po      | Char Acc: 4/5
# True: 4o2s       | Pred: 4o2s       | Char Acc: 4/4
# True: 4ofpfnr    | Pred: 4ofpfnp    | Char Acc: 6/7
# True: 4orw5      | Pred: 4orw5      | Char Acc: 5/5
# True: 4otur3lm   | Pred: 40tur3lm   | Char Acc: 7/8
# True: 4ox0xwz    | Pred: 4ox0xwz    | Char Acc: 7/7
# True: 4ozs1      | Pred: gq2s1      | Char Acc: 2/5
# True: 4pz2t1zb   | Pred: 4pz2t1z8   | Char Acc: 7/8
# True: 4rlub61    | Pred: 4rw861     | Char Acc: 2/7
# True: 4sc9       | Pred: 4sc9       | Char Acc: 4/4
# True: 4sotv      | Pred: 4sotw      | Char Acc: 4/5
# True: 4vzdt      | Pred: 4vzd1      | Char Acc: 4/5
# True: 4w2d1      | Pred: 4w2d1      | Char Acc: 5/5
# True: 4wqu       | Pred: 4wqu       | Char Acc: 4/4
# True: 4y8s0ox    | Pred: 4y8s00x    | Char Acc: 6/7
# True: 4zr0ay     | Pred: 4q70vy     | Char Acc: 3/6
# True: 505bfqaw   | Pred: g0sb94ru   | Char Acc: 2/8
# True: 51tm1m     | Pred: 51tm1m     | Char Acc: 6/6
# True: 52cr       | Pred: t2cw       | Char Acc: 2/4
# True: 5541y      | Pred: ss41y      | Char Acc: 3/5
# True: 56zqhv     | Pred: 56zghv     | Char Acc: 5/6
# True: 57aktxh    | Pred: 57aktxh    | Char Acc: 7/7
# True: 57l7ozfm   | Pred: 57ll70zfm  | Char Acc: 3/8
# True: 57mwra     | Pred: 67mwrd     | Char Acc: 4/6
# True: 57z6amy5   | Pred: 57z6dmv5   | Char Acc: 6/8
# True: 58vxyzo    | Pred: 58vxyz0    | Char Acc: 6/7
# True: 59cjavrg   | Pred: 59cjavrg   | Char Acc: 8/8
# True: 5ao2       | Pred: 5a02       | Char Acc: 3/4
# True: 5ax4gqv8   | Pred: 5ax4gqy8   | Char Acc: 7/8
# True: 5bsl06     | Pred: jqs28g     | Char Acc: 1/6
# True: 5buf       | Pred: 5buc       | Char Acc: 3/4
# True: 5bv9m      | Pred: 5bv9m      | Char Acc: 5/5
# True: 5d7659     | Pred: gdteg9     | Char Acc: 2/6
# True: 5dhl0wds   | Pred: gdn1au0g   | Char Acc: 1/8
# True: 5e8nthfj   | Pred: se8n7af    | Char Acc: 4/8
# True: 5ew8rwby   | Pred: 5ew8rmav   | Char Acc: 5/8
# True: 5fh6qvjv   | Pred: 5fx5qvjv   | Char Acc: 6/8
# True: 5fx3r3h    | Pred: 3fx3n3a    | Char Acc: 4/7
# True: 5g3zxw6n   | Pred: 5g3zxh8n   | Char Acc: 6/8
# True: 5gnom      | Pred: 59d9m      | Char Acc: 2/5
# True: 5gxru5c    | Pred: 5ghrusc    | Char Acc: 5/7
# True: 5gz2f      | Pred: 5g22f      | Char Acc: 4/5
# True: 5hquho     | Pred: 5hquho     | Char Acc: 6/6
# True: 5ipve      | Pred: 5ipxe      | Char Acc: 4/5
# True: 5iyp       | Pred: 5iun       | Char Acc: 2/4
# True: 5kag       | Pred: 4hag       | Char Acc: 2/4
# True: 5klh       | Pred: 5klh       | Char Acc: 4/4
# True: 5lqfxb     | Pred: 51ofxl     | Char Acc: 3/6
# True: 5mi1hb     | Pred: 5mi1hb     | Char Acc: 6/6
# True: 5nkkc244   | Pred: 5nhhc244   | Char Acc: 6/8
# True: 5ns95      | Pred: 5ns95      | Char Acc: 5/5
# True: 5oqszg     | Pred: 5qs1g      | Char Acc: 1/6
# True: 5qktumj    | Pred: 6qktumj    | Char Acc: 6/7
# True: 5qzyntfq   | Pred: 5qzyntfq   | Char Acc: 8/8
# True: 5rc37      | Pred: 5r37       | Char Acc: 2/5
# True: 5rnv1ah1   | Pred: 5ny1ohp    | Char Acc: 1/8
# True: 5rrvmra    | Pred: 5rrvmra    | Char Acc: 7/7
# True: 5ry4908    | Pred: sr44qob    | Char Acc: 2/7
# True: 5u24m      | Pred: 5u24m      | Char Acc: 5/5
# True: 5u5bn      | Pred: y58x       | Char Acc: 0/5
# True: 5u6kf9x    | Pred: suehf8p    | Char Acc: 2/7
# True: 5umc       | Pred: 5umc       | Char Acc: 4/4
# True: 5unc7      | Pred: sung7      | Char Acc: 3/5
# True: 5unrn      | Pred: gunfn      | Char Acc: 3/5
# True: 5unt2o     | Pred: 5unt2o     | Char Acc: 6/6
# True: 5wqfn9sb   | Pred: 8wqm96s    | Char Acc: 3/8
# True: 5x53y583   | Pred: 3x53y383   | Char Acc: 6/8
# True: 5xdkm      | Pred: 5xdkm      | Char Acc: 5/5
# True: 5xg9       | Pred: sxg9       | Char Acc: 3/4
# True: 5xnhd3u    | Pred: 6nnhd3u    | Char Acc: 5/7
# True: 5yr6km     | Pred: 5yr6km     | Char Acc: 6/6
# True: 5z4z       | Pred: 5z42       | Char Acc: 3/4
# True: 5z6pplh4   | Pred: vc2rnxn4   | Char Acc: 1/8
# True: 5z9sa      | Pred: 5z9sa      | Char Acc: 5/5
# True: 5zlui1t    | Pred: 5zlui1t    | Char Acc: 7/7
# True: 6046f2bl   | Pred: b04gfzjp   | Char Acc: 3/8
# True: 60dmyc0q   | Pred: 60dmyc0q   | Char Acc: 8/8
# True: 60rk8nk7   | Pred: 60rk8nx7   | Char Acc: 7/8
# True: 61mxp8b    | Pred: 61mxp8g    | Char Acc: 6/7
# True: 62h2rq     | Pred: 62h2rq     | Char Acc: 6/6
# True: 63xk       | Pred: 63xk       | Char Acc: 4/4
# True: 63zdn      | Pred: b32dn      | Char Acc: 3/5
# True: 64alz      | Pred: 64olz      | Char Acc: 4/5
# True: 64o042     | Pred: 44qq42     | Char Acc: 3/6
# True: 64q0       | Pred: 64q0       | Char Acc: 4/4
# True: 66qv60     | Pred: 664i6d     | Char Acc: 3/6
# True: 66yeec0o   | Pred: e6yeec0p   | Char Acc: 6/8
# True: 674yz      | Pred: s74yl      | Char Acc: 3/5
# True: 6885kiy    | Pred: 34ky       | Char Acc: 0/7
# True: 6887qv     | Pred: 6887ov     | Char Acc: 5/6
# True: 68nyv      | Pred: 68yyu      | Char Acc: 3/5
# True: 69a27m     | Pred: 69a27m     | Char Acc: 6/6
# True: 6b8qqt     | Pred: 6b8qqt     | Char Acc: 6/6
# True: 6cn8khq    | Pred: bn8hko     | Char Acc: 1/7
# True: 6dr3       | Pred: md1w       | Char Acc: 1/4
# True: 6e8ky5vl   | Pred: 6e8hy5vj   | Char Acc: 6/8
# True: 6ezy       | Pred: 6e2y       | Char Acc: 3/4
# True: 6gmo0yhp   | Pred: 6gmo0yhp   | Char Acc: 8/8
# True: 6i3x4ab2   | Pred: g13x4ab2   | Char Acc: 6/8
# True: 6i4pw      | Pred: 6i4pw      | Char Acc: 5/5
# True: 6ip3gj8w   | Pred: 6i03gjew   | Char Acc: 6/8
# True: 6jeolrb    | Pred: 6jeolrb    | Char Acc: 7/7
# True: 6jgczv     | Pred: q          | Char Acc: 0/6
# True: 6k8o3yk    | Pred: 6k803yk    | Char Acc: 6/7
# True: 6lkxo5     | Pred: 6lkx05     | Char Acc: 5/6
# True: 6mh8nbc    | Pred: 6mn9n8c    | Char Acc: 4/7
# True: 6nez       | Pred: 6nez       | Char Acc: 4/4
# True: 6nizx      | Pred: gmfzx      | Char Acc: 2/5
# True: 6oqlrct    | Pred: 6cqlvcz    | Char Acc: 4/7
# True: 6p9kg      | Pred: ap3x8      | Char Acc: 1/5
# True: 6rn1       | Pred: 6rs1       | Char Acc: 3/4
# True: 6rqy5      | Pred: grqy5      | Char Acc: 4/5
# True: 6rsm5vbv   | Pred: 6rsm5v8y   | Char Acc: 6/8
# True: 6s82khq    | Pred: 6s82hhq    | Char Acc: 6/7
# True: 6t2f1      | Pred: 6t2f1      | Char Acc: 5/5
# True: 6tp0xi     | Pred: 6tpoxi     | Char Acc: 5/6
# True: 6u702jo    | Pred: 647d2j0    | Char Acc: 4/7
# True: 6uc8lxm    | Pred: ejc8lxm    | Char Acc: 5/7
# True: 6ud6o      | Pred: 6nj6z      | Char Acc: 2/5
# True: 6uj1k      | Pred: 6u3vk      | Char Acc: 3/5
# True: 6umph5p0   | Pred: 6umph5p0   | Char Acc: 8/8
# True: 6vt9       | Pred: 6v79       | Char Acc: 3/4
# True: 6xhz       | Pred: 6xhz       | Char Acc: 4/4
# True: 6yjb6      | Pred: syj86      | Char Acc: 3/5
# True: 6yub4j6    | Pred: 6yu84j6    | Char Acc: 6/7
# True: 6ziffcz    | Pred: 5ziffcz    | Char Acc: 6/7
# True: 70vh       | Pred: 70uh       | Char Acc: 3/4
# True: 71uitis    | Pred: 71u1r1g    | Char Acc: 3/7
# True: 728h       | Pred: 728h       | Char Acc: 4/4
# True: 72cr       | Pred: 72ca       | Char Acc: 3/4
# True: 72ok       | Pred: 72ok       | Char Acc: 4/4
# True: 72qrkw     | Pred: 720rku     | Char Acc: 4/6
# True: 73z8hl     | Pred: g0zghl     | Char Acc: 3/6
# True: 74d5nqg7   | Pred: 74d9nq9    | Char Acc: 5/8
# True: 75jc4s     | Pred: 75sc4s     | Char Acc: 5/6
# True: 765xos8    | Pred: 76sh0gg    | Char Acc: 2/7
# True: 78l9       | Pred: 78l9       | Char Acc: 4/4
# True: 797v       | Pred: 7g7y       | Char Acc: 2/4
# True: 79coxr     | Pred: 79cqxr     | Char Acc: 5/6
# True: 79ioqkt    | Pred: 79ioqkt    | Char Acc: 7/7
# True: 79kr       | Pred: 7gkn       | Char Acc: 2/4
# True: 79n1       | Pred: 79m4       | Char Acc: 2/4
# True: 7aj8s1cr   | Pred: 7318srr    | Char Acc: 3/8
# True: 7atr4vpn   | Pred: 7ate4vph   | Char Acc: 6/8
# True: 7cbzihb3   | Pred: 7wbcmax    | Char Acc: 2/8
# True: 7ch9mno    | Pred: 7ck9mno    | Char Acc: 6/7
# True: 7d02g      | Pred: 7d02g      | Char Acc: 5/5
# True: 7dfpwcv    | Pred: 7dfpwcu    | Char Acc: 6/7
# True: 7dp41      | Pred: 7dp41      | Char Acc: 5/5
# True: 7dxi       | Pred: 7dxi       | Char Acc: 4/4
# True: 7e5o36h    | Pred: 7qboaah    | Char Acc: 3/7
# True: 7f3t77yk   | Pred: 7q3i77yk   | Char Acc: 6/8
# True: 7f53hf     | Pred: 9faahf     | Char Acc: 3/6
# True: 7gdnfemv   | Pred: igdn1emv   | Char Acc: 6/8
# True: 7h0a       | Pred: 7hoa       | Char Acc: 3/4
# True: 7i1o5e3    | Pred: 7i1g523    | Char Acc: 5/7
# True: 7iiyi4h    | Pred: 71iyi4h    | Char Acc: 6/7
# True: 7jb15      | Pred: ldtg       | Char Acc: 0/5
# True: 7juo675    | Pred: 7jso675    | Char Acc: 6/7
# True: 7ma7p      | Pred: mo4p       | Char Acc: 0/5
# True: 7n9jlm     | Pred: 7x9jlw     | Char Acc: 4/6
# True: 7olxc3k    | Pred: 70lxc3k    | Char Acc: 6/7
# True: 7oq8       | Pred: 70q9       | Char Acc: 2/4
# True: 7q0agge    | Pred: 7q0aggq    | Char Acc: 6/7
# True: 7q0s9      | Pred: 7q0a9      | Char Acc: 4/5
# True: 7qbyo      | Pred: 7q8yo      | Char Acc: 4/5
# True: 7qz0lfx    | Pred: 7qz0ifx    | Char Acc: 6/7
# True: 7rhv9      | Pred: 3xhvs      | Char Acc: 2/5
# True: 7ro3nfy    | Pred: 7ro3fy     | Char Acc: 4/7
# True: 7tei       | Pred: 7bq8       | Char Acc: 1/4
# True: 7udyuhg    | Pred: 7udyu4g    | Char Acc: 6/7
# True: 7uj27      | Pred: 7ujc7      | Char Acc: 4/5
# True: 7uygzl     | Pred: 7uygzf     | Char Acc: 5/6
# True: 7v1pp      | Pred: 7v7pp      | Char Acc: 4/5
# True: 7vs7l      | Pred: vs1l       | Char Acc: 0/5
# True: 7vseu      | Pred: 7vseu      | Char Acc: 5/5
# True: 7xd9dnsu   | Pred: 7ud9dmsu   | Char Acc: 6/8
# True: 7xfza9sy   | Pred: 7xfza9sy   | Char Acc: 8/8
# True: 7y05t      | Pred: 7jvc15t    | Char Acc: 1/5
# True: 7yd13j     | Pred: xdisk      | Char Acc: 0/6
# True: 7zhp       | Pred: 7zhp       | Char Acc: 4/4
# True: 7zns       | Pred: 7zns       | Char Acc: 4/4
# True: 80fntlo    | Pred: 80fntlo    | Char Acc: 7/7
# True: 80qkq      | Pred: 8oqhq      | Char Acc: 3/5
# True: 80xo       | Pred: 80re       | Char Acc: 2/4
# True: 81dbfmjt   | Pred: 81dbfmjf   | Char Acc: 7/8
# True: 81jv       | Pred: 81jv       | Char Acc: 4/4
# True: 83ii1ma7   | Pred: u3ii1mq7   | Char Acc: 6/8
# True: 8437vw2    | Pred: n137vwc    | Char Acc: 4/7
# True: 845ios     | Pred: 845ias     | Char Acc: 5/6
# True: 847n4v     | Pred: 847n4v     | Char Acc: 6/6
# True: 857txd     | Pred: 857txd     | Char Acc: 6/6
# True: 857u       | Pred: a7v        | Char Acc: 0/4
# True: 85yt3      | Pred: d8yi3      | Char Acc: 2/5
# True: 86zf1      | Pred: 86zf1      | Char Acc: 5/5
# True: 88do       | Pred: 33g0       | Char Acc: 0/4
# True: 88gtnpju   | Pred: 88gtnpju   | Char Acc: 8/8
# True: 8954       | Pred: 89s4       | Char Acc: 3/4
# True: 89uxia     | Pred: gguhig     | Char Acc: 2/6
# True: 8a27       | Pred: 8a27       | Char Acc: 4/4
# True: 8cmn       | Pred: 8cmn       | Char Acc: 4/4
# True: 8drskum    | Pred: 8drshum    | Char Acc: 6/7
# True: 8dz3       | Pred: 8dz3       | Char Acc: 4/4
# True: 8ej7j      | Pred: 0ej7j      | Char Acc: 4/5
# True: 8eqthhxs   | Pred: 8eqlwhxs   | Char Acc: 6/8
# True: 8f37hk9    | Pred: 9f97hk9    | Char Acc: 5/7
# True: 8fa95b     | Pred: 8fa95b     | Char Acc: 6/6
# True: 8fh1jn7o   | Pred: 8fh1ja7c   | Char Acc: 6/8
# True: 8fhvr      | Pred: 8fhur      | Char Acc: 4/5
# True: 8ga7       | Pred: 6ga7       | Char Acc: 3/4
# True: 8gjjfa     | Pred: 8qjuf2     | Char Acc: 3/6
# True: 8gs2o4ht   | Pred: bes204h1   | Char Acc: 4/8
# True: 8gti       | Pred: 8gt1       | Char Acc: 3/4
# True: 8gvjbeg    | Pred: 8gvjbeg    | Char Acc: 7/7
# True: 8haa6hf    | Pred: ghoq5m     | Char Acc: 1/7
# True: 8hr836     | Pred: 8hr836     | Char Acc: 6/6
# True: 8ilfoyvf   | Pred: 83b909dr   | Char Acc: 1/8
# True: 8jhd43     | Pred: ejhd4s     | Char Acc: 4/6
# True: 8jmqsxc    | Pred: djmqsxg    | Char Acc: 5/7
# True: 8jqv6j     | Pred: 8jqv6j     | Char Acc: 6/6
# True: 8jyb       | Pred: 5jyb       | Char Acc: 3/4
# True: 8k5y2      | Pred: 8ksy2      | Char Acc: 4/5
# True: 8kpdpt     | Pred: 8kpqpt     | Char Acc: 5/6
# True: 8m5k7      | Pred: 8m5k7      | Char Acc: 5/5
# True: 8p2da      | Pred: 8p2oq      | Char Acc: 3/5
# True: 8py2       | Pred: 8py2       | Char Acc: 4/4
# True: 8ry9l4e    | Pred: gf49l4y    | Char Acc: 3/7
# True: 8s3cl      | Pred: 8s3cl      | Char Acc: 5/5
# True: 8sjkrn     | Pred: 8skrn      | Char Acc: 2/6
# True: 8t5ylkn    | Pred: qtgylkn    | Char Acc: 5/7
# True: 8t95       | Pred: 8t95       | Char Acc: 4/4
# True: 8u7c6      | Pred: zu7ck      | Char Acc: 3/5
# True: 8vj93y     | Pred: bvjy3y     | Char Acc: 4/6
# True: 8vks9h     | Pred: 8uhs9n     | Char Acc: 3/6
# True: 8vlq5ln    | Pred: 8vlq5ln    | Char Acc: 7/7
# True: 8vs59cma   | Pred: gvg9cqd    | Char Acc: 1/8
# True: 8vvo6nxj   | Pred: 8vv0gnxj   | Char Acc: 6/8
# True: 8w853lv    | Pred: 8w8531v    | Char Acc: 6/7
# True: 8wcq       | Pred: 8wcq       | Char Acc: 4/4
# True: 8xbs5m1    | Pred: 8xbs5m1    | Char Acc: 7/7
# True: 8y3quw     | Pred: 8y3quw     | Char Acc: 6/6
# True: 8y9a       | Pred: 849a       | Char Acc: 3/4
# True: 8yeix3b2   | Pred: 64eix3q2   | Char Acc: 5/8
# True: 8z5y       | Pred: a8d4       | Char Acc: 0/4
# True: 905i4de    | Pred: 905i4de    | Char Acc: 7/7
# True: 911qxoxi   | Pred: 9qx0j      | Char Acc: 1/8
# True: 916r       | Pred: 916r       | Char Acc: 4/4
# True: 91v56clg   | Pred: 9lcs6edq   | Char Acc: 2/8
# True: 92itgl     | Pred: 92itgi     | Char Acc: 5/6
# True: 92mhb      | Pred: 32mhq      | Char Acc: 3/5
# True: 93tlh      | Pred: 93tlh      | Char Acc: 5/5
# True: 94k7yft    | Pred: 94k7yft    | Char Acc: 7/7
# True: 95hgda     | Pred: 9x37a      | Char Acc: 1/6
# True: 95j98se    | Pred: g5j98sa    | Char Acc: 5/7
# True: 95pcp5d    | Pred: 3qzp3d     | Char Acc: 0/7
# True: 95ticg     | Pred: 95ficg     | Char Acc: 5/6
# True: 96wm       | Pred: 9jwn       | Char Acc: 2/4
# True: 97vl       | Pred: 97ul       | Char Acc: 3/4
# True: 982zt      | Pred: 982zt      | Char Acc: 5/5
# True: 989gqi     | Pred: 3ggg4t     | Char Acc: 1/6
# True: 98en60a    | Pred: 98m60r     | Char Acc: 2/7
# True: 98kt9if    | Pred: 9sk69z6    | Char Acc: 3/7
# True: 98zdn      | Pred: 982dn      | Char Acc: 4/5
# True: 9a8w       | Pred: 9a8w       | Char Acc: 4/4
# True: 9abo       | Pred: 9abo       | Char Acc: 4/4
# True: 9bf9       | Pred: 3e9        | Char Acc: 0/4
# True: 9cd1r      | Pred: 9cj1r      | Char Acc: 4/5
# True: 9d6a       | Pred: 9d6a       | Char Acc: 4/4
# True: 9e1e5t3    | Pred: 9e1e5t3    | Char Acc: 7/7
# True: 9ecqisn    | Pred: 9ecqi8d    | Char Acc: 5/7
# True: 9eub       | Pred: 9eu8       | Char Acc: 3/4
# True: 9h7ucby    | Pred: 9h7uc6y    | Char Acc: 6/7
# True: 9ic2560    | Pred: 9ic2560    | Char Acc: 7/7
# True: 9jne       | Pred: 3jne       | Char Acc: 3/4
# True: 9jr3bv6    | Pred: 9jfabv6    | Char Acc: 5/7
# True: 9jud9      | Pred: jud        | Char Acc: 0/5
# True: 9k0r3u89   | Pred: 9n0r3489   | Char Acc: 6/8
# True: 9kat       | Pred: mtp7       | Char Acc: 0/4
# True: 9kdflf     | Pred: 9nqflf     | Char Acc: 4/6
# True: 9ko8gb7    | Pred: 9kdbg87    | Char Acc: 4/7
# True: 9kt2e50    | Pred: 9bi2es0    | Char Acc: 4/7
# True: 9ky868f    | Pred: 9ky868f    | Char Acc: 7/7
# True: 9l7bkna    | Pred: 917bkne    | Char Acc: 5/7
# True: 9o9vjrf    | Pred: 9o9vjr6    | Char Acc: 6/7
# True: 9odszww    | Pred: 90dszwh    | Char Acc: 5/7
# True: 9pzd05     | Pred: 9pzdq5     | Char Acc: 5/6
# True: 9q8et      | Pred: 9q8ac      | Char Acc: 3/5
# True: 9q8x5jar   | Pred: 9qga64qr   | Char Acc: 3/8
# True: 9roi       | Pred: 9roi       | Char Acc: 4/4
# True: 9roz       | Pred: 9roz       | Char Acc: 4/4
# True: 9snz6yol   | Pred: 9snz6yol   | Char Acc: 8/8
# True: 9tjryy     | Pred: 7ts8yy     | Char Acc: 3/6
# True: 9tml6      | Pred: 9tmlg      | Char Acc: 4/5
# True: 9uto8      | Pred: 9uto8      | Char Acc: 5/5
# True: 9uvr0ib    | Pred: 3ptrb      | Char Acc: 1/7
# True: 9vvf       | Pred: 9vuf       | Char Acc: 3/4
# True: 9w2kf6     | Pred: gwzk56     | Char Acc: 3/6
# True: 9w7u       | Pred: qw7u       | Char Acc: 3/4
# True: 9x4a       | Pred: 9x4a       | Char Acc: 4/4
# True: 9xawh3yg   | Pred: m3y4       | Char Acc: 0/8
# True: 9xrjkpv3   | Pred: qrr9kpv3   | Char Acc: 5/8
# True: 9y4j9qb5   | Pred: 9y4j9qb5   | Char Acc: 8/8
# True: 9ylh81c3   | Pred: 9yaapg     | Char Acc: 2/8
# True: a05d1v     | Pred: 805a1v     | Char Acc: 4/6
# True: a0781s     | Pred: aq78i9     | Char Acc: 3/6
# True: a09mmm     | Pred: h09mmm     | Char Acc: 5/6
# True: a0p3v7     | Pred: aqq3v7     | Char Acc: 4/6
# True: a0sp1ytr   | Pred: a0sp1yfr   | Char Acc: 7/8
# True: a0vz       | Pred: a0vz       | Char Acc: 4/4
# True: a10n8u7a   | Pred: ai0x8u7a   | Char Acc: 6/8
# True: a19teh     | Pred: ai9tgh     | Char Acc: 4/6
# True: a3am       | Pred: q3om       | Char Acc: 2/4
# True: a3lb       | Pred: a3lb       | Char Acc: 4/4
# True: a4eer5     | Pred: a4eer5     | Char Acc: 6/6
# True: a6d6ejh    | Pred: a666ej8    | Char Acc: 5/7
# True: a7boq      | Pred: a7b00      | Char Acc: 3/5
# True: a7hna      | Pred: a7hma      | Char Acc: 4/5
# True: a7nft      | Pred: a7nff      | Char Acc: 4/5
# True: a9wr       | Pred: a9wa       | Char Acc: 3/4
# True: ab3t       | Pred: ab3t       | Char Acc: 4/4
# True: abkn       | Pred: a8kn       | Char Acc: 3/4
# True: ac0k2ac    | Pred: ac0k2ac    | Char Acc: 7/7
# True: acukt0vo   | Pred: acukt0vo   | Char Acc: 8/8
# True: adj6kf8    | Pred: o38xfa     | Char Acc: 0/7
# True: adjw       | Pred: a03w       | Char Acc: 2/4
# True: aettyxdl   | Pred: rdz1ysdl   | Char Acc: 3/8
# True: aeylheco   | Pred: aeylhec0   | Char Acc: 7/8
# True: af5tfh     | Pred: af57qw     | Char Acc: 3/6
# True: affv2      | Pred: affv2      | Char Acc: 5/5
# True: ag2hnuw4   | Pred: p6d4dgdr   | Char Acc: 0/8
# True: agti       | Pred: act1       | Char Acc: 2/4
# True: ah9z       | Pred: ah9z       | Char Acc: 4/4
# True: ahmw48r0   | Pred: ami480     | Char Acc: 1/8
# True: ahpho      | Pred: fhpk0      | Char Acc: 2/5
# True: ai6j7gu    | Pred: aicj7gu    | Char Acc: 6/7
# True: airp       | Pred: a1rp       | Char Acc: 3/4
# True: aiu0q3n5   | Pred: siu0q3n5   | Char Acc: 7/8
# True: aiwh       | Pred: aimk       | Char Acc: 2/4
# True: aj0w0o     | Pred: ajowoa     | Char Acc: 3/6
# True: ajej       | Pred: ajej       | Char Acc: 4/4
# True: ajst       | Pred: ajst       | Char Acc: 4/4
# True: akc39      | Pred: okc39      | Char Acc: 4/5
# True: akf8o1     | Pred: qhp8o1     | Char Acc: 3/6
# True: al5oidta   | Pred: ol5oidfo   | Char Acc: 5/8
# True: alj0qd     | Pred: 4lj0q9     | Char Acc: 4/6
# True: am1jamnx   | Pred: hwzjhwnx   | Char Acc: 3/8
# True: am3zutsp   | Pred: iy3zv7sf   | Char Acc: 3/8
# True: ambcqo     | Pred: bm6cqo     | Char Acc: 4/6
# True: angpr      | Pred: hngpp      | Char Acc: 3/5
# True: aogwhj3y   | Pred: a0gwhj3y   | Char Acc: 7/8
# True: aotaaj     | Pred: ao1aqj     | Char Acc: 4/6
# True: aova       | Pred: q0va       | Char Acc: 2/4
# True: ap7v1co5   | Pred: oa7v1oo5   | Char Acc: 5/8
# True: apf9kx     | Pred: hafghx     | Char Acc: 2/6
# True: api94      | Pred: jpi94      | Char Acc: 4/5
# True: aqq8       | Pred: aqq8       | Char Acc: 4/4
# True: asdrpxpf   | Pred: aadrdxqf   | Char Acc: 5/8
# True: ati99er    | Pred: a4i99er    | Char Acc: 6/7
# True: atwip0     | Pred: atwip0     | Char Acc: 6/6
# True: aumb       | Pred: a0         | Char Acc: 1/4
# True: aup1v      | Pred: pup1v      | Char Acc: 4/5
# True: awsb9x     | Pred: 3wsb9a     | Char Acc: 4/6
# True: axiy       | Pred: 9x1y       | Char Acc: 2/4
# True: aybws      | Pred: aybw5      | Char Acc: 4/5
# True: azci8sm    | Pred: hzcib5m    | Char Acc: 4/7
# True: b10cjyh5   | Pred: 8idcjyh5   | Char Acc: 5/8
# True: b30srp     | Pred: 930srp     | Char Acc: 5/6
# True: b359qg64   | Pred: 8359qg64   | Char Acc: 7/8
# True: b37if3k    | Pred: 8371f3k    | Char Acc: 5/7
# True: b3okru3    | Pred: y3ok3u3    | Char Acc: 5/7
# True: b45viav3   | Pred: b4svlav2   | Char Acc: 5/8
# True: b4bo0u     | Pred: b4b00u     | Char Acc: 5/6
# True: b4dmm      | Pred: bgdmm      | Char Acc: 4/5
# True: b4gvghd    | Pred: b4gughd    | Char Acc: 6/7
# True: b842ks     | Pred: bg42ts     | Char Acc: 4/6
# True: b9opk      | Pred: b9opk      | Char Acc: 5/5
# True: bayv1bf    | Pred: 0ogvi0f    | Char Acc: 2/7
# True: bc8nk      | Pred: bc8nk      | Char Acc: 5/5
# True: be1nxzo    | Pred: 4bh1yy9    | Char Acc: 0/7
# True: be5bvz     | Pred: 8es8vz     | Char Acc: 3/6
# True: berxkmm    | Pred: berxkmm    | Char Acc: 7/7
# True: bf90d36    | Pred: g9qgg88    | Char Acc: 0/7
# True: bg2l       | Pred: bg21       | Char Acc: 3/4
# True: bgrel      | Pred: ugra1      | Char Acc: 2/5
# True: bh8fm4     | Pred: bh8em4     | Char Acc: 5/6
# True: bi4tc1t    | Pred: js1lz1l    | Char Acc: 1/7
# True: bkgkg      | Pred: bkska      | Char Acc: 3/5
# True: bksz4      | Pred: 8k5z4      | Char Acc: 3/5
# True: ble2       | Pred: dug2       | Char Acc: 1/4
# True: bms2xok    | Pred: nms2xok    | Char Acc: 6/7
# True: bof0       | Pred: aof0       | Char Acc: 3/4
# True: borm8q     | Pred: b0rm9q     | Char Acc: 4/6
# True: botts4p    | Pred: betts4p    | Char Acc: 6/7
# True: bpc5hioe   | Pred: bpc5hioe   | Char Acc: 8/8
# True: bpqy       | Pred: bpqy       | Char Acc: 4/4
# True: br70       | Pred: bz7q       | Char Acc: 2/4
# True: bs8pvh     | Pred: 8s8pvh     | Char Acc: 5/6
# True: bsmh       | Pred: bsmh       | Char Acc: 4/4
# True: btzh       | Pred: btzh       | Char Acc: 4/4
# True: bwkx       | Pred: 8wkx       | Char Acc: 3/4
# True: by0nq5     | Pred: b0nq5      | Char Acc: 1/6
# True: bzb9o8f7   | Pred: 9189o8r3   | Char Acc: 3/8
# True: bzx2       | Pred: bzx        | Char Acc: 3/4
# True: c0u7m      | Pred: c0u7m      | Char Acc: 5/5
# True: c1dq8      | Pred: cidqb      | Char Acc: 3/5
# True: c1ja0      | Pred: c1ja0      | Char Acc: 5/5
# True: c1zjhlz    | Pred: eizjhlz    | Char Acc: 5/7
# True: c3mh       | Pred: c3mh       | Char Acc: 4/4
# True: c56kq      | Pred: c56kq      | Char Acc: 5/5
# True: c5ibod     | Pred: c5i80d     | Char Acc: 4/6
# True: c61s       | Pred: c61s       | Char Acc: 4/4
# True: c8egw6f    | Pred: g8egw6f    | Char Acc: 6/7
# True: c8lipq3q   | Pred: i8lip038   | Char Acc: 5/8
# True: c9azl      | Pred: c9a2l      | Char Acc: 4/5
# True: cb0zfw     | Pred: c80zfu     | Char Acc: 4/6
# True: cc8am3d    | Pred: cc8am3d    | Char Acc: 7/7
# True: ccd2k      | Pred: ccd2k      | Char Acc: 5/5
# True: ccmk       | Pred: ccmk       | Char Acc: 4/4
# True: ccphknh    | Pred: ccphkak    | Char Acc: 5/7
# True: cczqr7m    | Pred: cczq41m    | Char Acc: 5/7
# True: cd2h9      | Pred: ok2hq      | Char Acc: 2/5
# True: cd7zah     | Pred: co7zan     | Char Acc: 4/6
# True: cdavw      | Pred: cdavuj     | Char Acc: 4/5
# True: celi0l6c   | Pred: celiolgc   | Char Acc: 6/8
# True: cezc6r9    | Pred: cezt6a9    | Char Acc: 5/7
# True: cfqgi      | Pred: cfqsi      | Char Acc: 4/5
# True: cg16       | Pred: cg16       | Char Acc: 4/4
# True: ch9y67     | Pred: sn1nt7     | Char Acc: 1/6
# True: chle6v3    | Pred: chlf6v3    | Char Acc: 6/7
# True: chs21      | Pred: cwi21      | Char Acc: 3/5
# True: ci2yg      | Pred: c1w49      | Char Acc: 1/5
# True: ci82       | Pred: ci82       | Char Acc: 4/4
# True: ciixax     | Pred: ciixax     | Char Acc: 6/6
# True: ck2pg9     | Pred: cx2pg7     | Char Acc: 4/6
# True: ckowcc3w   | Pred: ekowcc3w   | Char Acc: 7/8
# True: ckxl       | Pred: ckxi       | Char Acc: 3/4
# True: clc43      | Pred: clc43      | Char Acc: 5/5
# True: clivi      | Pred: o1iy1      | Char Acc: 1/5
# True: clsev      | Pred: e5ee       | Char Acc: 1/5
# True: cnm7d0b    | Pred: rm728e     | Char Acc: 0/7
# True: cnr0n      | Pred: cnr0r      | Char Acc: 4/5
# True: co6pmuf    | Pred: c06pmuf    | Char Acc: 6/7
# True: cpkb0lun   | Pred: cpk80lun   | Char Acc: 7/8
# True: cpuanl     | Pred: cpuan1     | Char Acc: 5/6
# True: cq4xj      | Pred: cqyx3      | Char Acc: 3/5
# True: ctwvndf2   | Pred: mowyndpe   | Char Acc: 3/8
# True: ctyged6    | Pred: ctqge08    | Char Acc: 4/7
# True: cukg       | Pred: guxg       | Char Acc: 2/4
# True: cuygj9     | Pred: tu70j7     | Char Acc: 2/6
# True: cvlz       | Pred: cvlz       | Char Acc: 4/4
# True: cvrclgjk   | Pred: cvrclgjk   | Char Acc: 8/8
# True: cwaqxmf    | Pred: cw4qxmf    | Char Acc: 6/7
# True: cwtje      | Pred: l7jf       | Char Acc: 0/5
# True: cwwtxxdn   | Pred: cwwtxx0n   | Char Acc: 7/8
# True: cxttv      | Pred: cvttv      | Char Acc: 4/5
# True: cy02lz06   | Pred: cjc94zdp   | Char Acc: 2/8
# True: czffkx6k   | Pred: czffkxgk   | Char Acc: 7/8
# True: d0ughk     | Pred: doughk     | Char Acc: 5/6
# True: d17ywi     | Pred: u17yw1     | Char Acc: 4/6
# True: d1p4       | Pred: d7p4       | Char Acc: 3/4
# True: d3badth    | Pred: d3bodth    | Char Acc: 6/7
# True: d4ag       | Pred: d4ag       | Char Acc: 4/4
# True: d4ls       | Pred: d4ls       | Char Acc: 4/4
# True: d5xs9bnn   | Pred: d5xsq8nn   | Char Acc: 6/8
# True: d5y0       | Pred: v5v0       | Char Acc: 2/4
# True: d61iogli   | Pred: d6i0gu     | Char Acc: 2/8
# True: d6jceo     | Pred: 361t4q     | Char Acc: 1/6
# True: d7tnt      | Pred: a7tnf      | Char Acc: 3/5
# True: d9bb       | Pred: d9bb       | Char Acc: 4/4
# True: d9dpyu     | Pred: d9dpyu     | Char Acc: 6/6
# True: d9yfbv     | Pred: dayf8v     | Char Acc: 4/6
# True: dbhfyd     | Pred: o94eyq     | Char Acc: 1/6
# True: dbj0x5     | Pred: dbjan5     | Char Acc: 4/6
# True: dbs1ca45   | Pred: ob51ca45   | Char Acc: 6/8
# True: ddq99w     | Pred: dpq99w     | Char Acc: 5/6
# True: dew2un6t   | Pred: dew2un6t   | Char Acc: 8/8
# True: df4i       | Pred: df4i       | Char Acc: 4/4
# True: dfzr1      | Pred: dfzr1      | Char Acc: 5/5
# True: dhgx       | Pred: ahgx       | Char Acc: 3/4
# True: dhol0      | Pred: dhol0      | Char Acc: 5/5
# True: difuege    | Pred: difuege    | Char Acc: 7/7
# True: diisew16   | Pred: 94is4w16   | Char Acc: 5/8
# True: dj8w71     | Pred: 418w7t     | Char Acc: 3/6
# True: djvh       | Pred: d1vh       | Char Acc: 3/4
# True: dkpffz3i   | Pred: dxpffz3i   | Char Acc: 7/8
# True: dl32zbu    | Pred: 4232zbo    | Char Acc: 4/7
# True: dlne7      | Pred: dne7       | Char Acc: 1/5
# True: dlsvh5cr   | Pred: disvh5cr   | Char Acc: 7/8
# True: dlu4       | Pred: dlu4       | Char Acc: 4/4
# True: dm6ocdl    | Pred: 0m6ocdl    | Char Acc: 6/7
# True: dmvd       | Pred: dmvd       | Char Acc: 4/4
# True: dnhr6      | Pred: qmws6      | Char Acc: 1/5
# True: dnstkc6    | Pred: 3ustkcg    | Char Acc: 4/7
# True: do05fv7a   | Pred: 90o5fv7n   | Char Acc: 4/8
# True: dogbl      | Pred: dogb1      | Char Acc: 4/5
# True: dooeac1    | Pred: d00eqc1    | Char Acc: 4/7
# True: dp8vc      | Pred: 0p8vc      | Char Acc: 4/5
# True: dpsf5sd    | Pred: dpsi5s4    | Char Acc: 5/7
# True: dqd8       | Pred: dqd9       | Char Acc: 3/4
# True: dr1f       | Pred: 0r1f       | Char Acc: 3/4
# True: drgu1a     | Pred: 8iywza     | Char Acc: 1/6
# True: dsgzv      | Pred: dggzv      | Char Acc: 4/5
# True: dstb9ae    | Pred: 0st89ae    | Char Acc: 5/7
# True: dt1mwp     | Pred: dt1mwp     | Char Acc: 6/6
# True: duloh3n6   | Pred: uuwhwb     | Char Acc: 1/8
# True: dxyz       | Pred: 0xyz       | Char Acc: 3/4
# True: dy1ok3v0   | Pred: dy10k3vc   | Char Acc: 6/8
# True: dydqsftd   | Pred: dydqsftd   | Char Acc: 8/8
# True: dzc50dkp   | Pred: d2csddxp   | Char Acc: 4/8
# True: dzjzg      | Pred: qyjzg      | Char Acc: 3/5
# True: e00w1ndt   | Pred: e00w1adt   | Char Acc: 7/8
# True: e0hie      | Pred: esfz       | Char Acc: 1/5
# True: e2yb5pxs   | Pred: erq85da5   | Char Acc: 2/8
# True: e3zwtu     | Pred: e3zwtu     | Char Acc: 6/6
# True: e59bi2u    | Pred: e0qbi0u    | Char Acc: 4/7
# True: e6n2vwe    | Pred: e6n2uwo    | Char Acc: 5/7
# True: e6pbcz1k   | Pred: e6pbcz1k   | Char Acc: 8/8
# True: e6ty48q    | Pred: e6ty48q    | Char Acc: 7/7
# True: e72avg8    | Pred: e72avg8    | Char Acc: 7/7
# True: e7r7op0    | Pred: k7r7opo    | Char Acc: 5/7
# True: e8diuj9    | Pred: o8dsuig    | Char Acc: 3/7
# True: e9gjyd61   | Pred: e7gjyd6i   | Char Acc: 6/8
# True: e9ho       | Pred: eqho       | Char Acc: 3/4
# True: eapsj      | Pred: eapu6      | Char Acc: 3/5
# True: eaqhlka4   | Pred: ooqhlhaq   | Char Acc: 4/8
# True: ecvjeott   | Pred: scvjeotf   | Char Acc: 6/8
# True: eeaveky    | Pred: eeaveny    | Char Acc: 6/7
# True: efzjeuuy   | Pred: efzjeuwy   | Char Acc: 7/8
# True: ehk38v     | Pred: ok4sgn     | Char Acc: 0/6
# True: ehnskhzj   | Pred: pho3hhzj   | Char Acc: 4/8
# True: eiavx3     | Pred: eiavx3     | Char Acc: 6/6
# True: ejpc940k   | Pred: eupc94ok   | Char Acc: 6/8
# True: ek0ky      | Pred: ek0kv      | Char Acc: 4/5
# True: emvs       | Pred: 6mvs       | Char Acc: 3/4
# True: eoivh      | Pred: esivh      | Char Acc: 4/5
# True: eq94jj     | Pred: eq94jj     | Char Acc: 6/6
# True: eq9vn3     | Pred: eq9vn3     | Char Acc: 6/6
# True: eqenl      | Pred: eqeni      | Char Acc: 4/5
# True: eqyl       | Pred: eqyi       | Char Acc: 3/4
# True: ermoo4     | Pred: qymoo4     | Char Acc: 4/6
# True: esay1v9    | Pred: e5ay1vq    | Char Acc: 5/7
# True: esikt      | Pred: t51kt      | Char Acc: 2/5
# True: essl       | Pred: sssl       | Char Acc: 3/4
# True: etfjev     | Pred: etfjev     | Char Acc: 6/6
# True: euup       | Pred: cuup       | Char Acc: 3/4
# True: evk9e1aa   | Pred: evk9e1aa   | Char Acc: 8/8
# True: ew211      | Pred: zuz1i      | Char Acc: 1/5
# True: ewikf      | Pred: ewikf      | Char Acc: 5/5
# True: ex2xa      | Pred: ex2xa      | Char Acc: 5/5
# True: exig       | Pred: exig       | Char Acc: 4/4
# True: exz3r1y4   | Pred: exz3r1y4   | Char Acc: 8/8
# True: exz3zi     | Pred: exz3zi     | Char Acc: 6/6
# True: ey72       | Pred: ey72       | Char Acc: 4/4
# True: eyk2zn91   | Pred: sykzzn91   | Char Acc: 6/8
# True: eyq05      | Pred: kya2p      | Char Acc: 1/5
# True: eyqul0     | Pred: eyqul0     | Char Acc: 6/6
# True: ez5h       | Pred: 8zsh       | Char Acc: 2/4
# True: eznvbmw    | Pred: eznvbmw    | Char Acc: 7/7
# True: f149       | Pred: f149       | Char Acc: 4/4
# True: f18eic     | Pred: fi8eic     | Char Acc: 5/6
# True: f1h0       | Pred: f1h0       | Char Acc: 4/4
# True: f1r4t      | Pred: f7r4t      | Char Acc: 4/5
# True: f2dmz      | Pred: f2dmz      | Char Acc: 5/5
# True: f3m80      | Pred: f3m80      | Char Acc: 5/5
# True: f40duv     | Pred: f40duv     | Char Acc: 6/6
# True: f48b3      | Pred: f4853      | Char Acc: 4/5
# True: f48o       | Pred: f40o       | Char Acc: 3/4
# True: f49sgark   | Pred: f49gghrk   | Char Acc: 6/8
# True: f5e9       | Pred: f5e9       | Char Acc: 4/4
# True: f5rf7a9    | Pred: k3nt7u9    | Char Acc: 2/7
# True: f6554      | Pred: f6554      | Char Acc: 5/5
# True: f68xqiqk   | Pred: f6axq1ok   | Char Acc: 5/8
# True: f73kv      | Pred: f73kv      | Char Acc: 5/5
# True: f95n2fh    | Pred: f9sn2fh    | Char Acc: 6/7
# True: f9e4h7     | Pred: f9eah7     | Char Acc: 5/6
# True: fazgm      | Pred: fargm      | Char Acc: 4/5
# True: fd1cwfhl   | Pred: h4hq4bkn   | Char Acc: 0/8
# True: fdb0       | Pred: gd80       | Char Acc: 2/4
# True: ff9w4m3    | Pred: ff9wam3    | Char Acc: 6/7
# True: ffeuj49    | Pred: q9qqg9q    | Char Acc: 0/7
# True: fgww       | Pred: fgww       | Char Acc: 4/4
# True: fhjk       | Pred: fhjk       | Char Acc: 4/4
# True: fkcd6c     | Pred: fkcd6c     | Char Acc: 6/6
# True: fkzdxrta   | Pred: ih1dxx1a   | Char Acc: 3/8
# True: fl725xft   | Pred: 7b7864p7   | Char Acc: 1/8
# True: fmg72z7c   | Pred: fmggz7c    | Char Acc: 3/8
# True: fmxc       | Pred: dadd       | Char Acc: 0/4
# True: fna1yfad   | Pred: fnq1yfqd   | Char Acc: 6/8
# True: fnbe5l     | Pred: tobq31     | Char Acc: 1/6
# True: fni3o      | Pred: fnizo      | Char Acc: 4/5
# True: fnszj      | Pred: fasz3      | Char Acc: 3/5
# True: fojc5      | Pred: fojc5      | Char Acc: 5/5
# True: fooa1y     | Pred: fqqa1y     | Char Acc: 4/6
# True: fp3l8gy    | Pred: fp318gy    | Char Acc: 6/7
# True: frf4       | Pred: frf4       | Char Acc: 4/4
# True: frg4r      | Pred: frgqr      | Char Acc: 4/5
# True: fuk189     | Pred: fuky84     | Char Acc: 4/6
# True: fukr6x06   | Pred: fjkr6x06   | Char Acc: 7/8
# True: fw652      | Pred: fw6s2      | Char Acc: 4/5
# True: fx8w6      | Pred: fh8w6      | Char Acc: 4/5
# True: fxakx8     | Pred: fxakx8     | Char Acc: 6/6
# True: fxb3wssu   | Pred: fxb3w53u   | Char Acc: 6/8
# True: fxy5kcx    | Pred: fxy5kcx    | Char Acc: 7/7
# True: fygzfbbv   | Pred: fygzf88v   | Char Acc: 6/8
# True: fyhq8      | Pred: fyhq8      | Char Acc: 5/5
# True: fyqrwuqw   | Pred: fyqrwuqw   | Char Acc: 8/8
# True: fyvpmvsh   | Pred: 13xpmsu    | Char Acc: 2/8
# True: fzgwqo     | Pred: fzgwg0     | Char Acc: 4/6
# True: fzr6zx     | Pred: fzr6zx     | Char Acc: 6/6
# True: g0atmsxc   | Pred: g0atmsxo   | Char Acc: 7/8
# True: g0lfj      | Pred: 8oipj      | Char Acc: 1/5
# True: g0ml0      | Pred: gomlq      | Char Acc: 3/5
# True: g1qy8      | Pred: g19y8      | Char Acc: 4/5
# True: g1sj8c     | Pred: g1oj3c     | Char Acc: 4/6
# True: g1zxvopk   | Pred: g1zxvopk   | Char Acc: 8/8
# True: g2d389y    | Pred: g4d3d9y    | Char Acc: 5/7
# True: g399jxe2   | Pred: g39qjxe2   | Char Acc: 7/8
# True: g3eoac0n   | Pred: g3e0ac0n   | Char Acc: 7/8
# True: g4pu       | Pred: g4pu       | Char Acc: 4/4
# True: g50tnn     | Pred: g50tnn     | Char Acc: 6/6
# True: g8jm5x5i   | Pred: gim5xa     | Char Acc: 1/8
# True: g9lyglwj   | Pred: g9jyglvj   | Char Acc: 6/8
# True: gatwbcv    | Pred: gatw8cv    | Char Acc: 6/7
# True: gaux8s     | Pred: gauk8s     | Char Acc: 5/6
# True: gbm3k      | Pred: gbm3k      | Char Acc: 5/5
# True: gbypds     | Pred: gbypds     | Char Acc: 6/6
# True: gc95       | Pred: go95       | Char Acc: 3/4
# True: gczr1sen   | Pred: 6czri5en   | Char Acc: 5/8
# True: gdg7h      | Pred: 9397h      | Char Acc: 2/5
# True: gdhkyad    | Pred: g0hh4ad    | Char Acc: 4/7
# True: gdqimd1p   | Pred: gdqimdip   | Char Acc: 7/8
# True: ge5tdvi    | Pred: ge5tavi    | Char Acc: 6/7
# True: gh210y     | Pred: oh2l0v     | Char Acc: 3/6
# True: ghdb       | Pred: ghdb       | Char Acc: 4/4
# True: gheilnvi   | Pred: gheilnvi   | Char Acc: 8/8
# True: gj8s       | Pred: qjqs       | Char Acc: 2/4
# True: gjj6pj     | Pred: ynmpu      | Char Acc: 0/6
# True: gk9zgds    | Pred: uk9zgd5    | Char Acc: 5/7
# True: gksyty     | Pred: yksdtd     | Char Acc: 3/6
# True: glsq6wv    | Pred: glsq6wv    | Char Acc: 7/7
# True: gm5klt6    | Pred: gm5klt6    | Char Acc: 7/7
# True: gmlevzei   | Pred: gmievzei   | Char Acc: 7/8
# True: gmqv9      | Pred: gmqv9      | Char Acc: 5/5
# True: go2lwcm    | Pred: c02lwcm    | Char Acc: 5/7
# True: god2llyl   | Pred: g0dllyl    | Char Acc: 3/8
# True: gq9od      | Pred: gq90p      | Char Acc: 3/5
# True: gqbmo      | Pred: agdme      | Char Acc: 1/5
# True: gqyue2     | Pred: gqyue2     | Char Acc: 6/6
# True: gr8ac      | Pred: gr9ac      | Char Acc: 4/5
# True: guvl       | Pred: guyl       | Char Acc: 3/4
# True: gw3l       | Pred: 6w3i       | Char Acc: 2/4
# ...
# True: uiu9qbp    | Pred: uiu9q8r    | Char Acc: 5/7
# True: uj33lkgd   | Pred: us331hgd   | Char Acc: 5/8
# True: uk7b       | Pred: ok7b       | Char Acc: 3/4
# True: ukna       | Pred: uknh       | Char Acc: 3/4
# True: ukpaowzr   | Pred: uhqoowzr   | Char Acc: 5/8
# True: ulb7ir     | Pred: y1b7ir     | Char Acc: 4/6
# True: um2ncoly   | Pred: um2ncoly   | Char Acc: 8/8
# True: umgjqz44   | Pred: cngje1qq   | Char Acc: 2/8
# True: umygl4rs   | Pred: umygc4rs   | Char Acc: 7/8
# True: unr4       | Pred: unrq       | Char Acc: 3/4
# True: uobiz      | Pred: uo8i2      | Char Acc: 3/5
# True: uow8r      | Pred: udw8r      | Char Acc: 4/5
# True: up14719    | Pred: ua7a77g    | Char Acc: 2/7
# True: upkljb     | Pred: upkijb     | Char Acc: 5/6
# True: uqa7       | Pred: uqa7       | Char Acc: 4/4
# True: uqdd8      | Pred: ugcdde     | Char Acc: 2/5
# True: uqvtzje    | Pred: u0vt2je    | Char Acc: 5/7
# True: urdsvx4    | Pred: urdsvx4    | Char Acc: 7/7
# True: uru17mq    | Pred: uru17mq    | Char Acc: 7/7
# True: usb3g      | Pred: j3b3g      | Char Acc: 3/5
# True: uspxt      | Pred: vspxt      | Char Acc: 4/5
# True: uuk0vwk    | Pred: uuk0vuk    | Char Acc: 6/7
# True: uv4a9chi   | Pred: uu4a9chi   | Char Acc: 7/8
# True: uvbv       | Pred: aubu       | Char Acc: 1/4
# True: uvt9       | Pred: uv79       | Char Acc: 3/4
# True: uwgf2      | Pred: uwgf2      | Char Acc: 5/5
# True: ux6fdl     | Pred: ux6fdi     | Char Acc: 5/6
# True: ux72og     | Pred: ux178q     | Char Acc: 2/6
# True: uxrd       | Pred: uxra       | Char Acc: 3/4
# True: uy0bk4pi   | Pred: cy0uk4pi   | Char Acc: 6/8
# True: uyj86      | Pred: uyj86      | Char Acc: 5/5
# True: uykm5t     | Pred: 4ynmst     | Char Acc: 3/6
# True: v2j7k7ho   | Pred: v2i7h7ho   | Char Acc: 6/8
# True: v2tx0x8    | Pred: v2tx0x8    | Char Acc: 7/7
# True: v3zi7      | Pred: v3zi7      | Char Acc: 5/5
# True: v4e3y      | Pred: u4e3y      | Char Acc: 4/5
# True: v4tv       | Pred: v4tv       | Char Acc: 4/4
# True: v4ua       | Pred: v1ca       | Char Acc: 2/4
# True: v74se      | Pred: v74se      | Char Acc: 5/5
# True: v7cb2d     | Pred: v7c82d     | Char Acc: 5/6
# True: v8un8hi    | Pred: v8un8h1    | Char Acc: 6/7
# True: v8zx       | Pred: y2k        | Char Acc: 0/4
# True: v932erc    | Pred: u932erc    | Char Acc: 6/7
# True: v96l5      | Pred: v96i5      | Char Acc: 4/5
# True: v9edw      | Pred: x4sow      | Char Acc: 1/5
# True: vbj0ok     | Pred: vbj00k     | Char Acc: 5/6
# True: vbwmzu0    | Pred: ybwmzu0    | Char Acc: 6/7
# True: vcdsf      | Pred: ucds6      | Char Acc: 3/5
# True: vclgq26    | Pred: vclgq26    | Char Acc: 7/7
# True: vcz077     | Pred: vc2077     | Char Acc: 5/6
# True: vdi82kz4   | Pred: qoj82xz4   | Char Acc: 4/8
# True: ve47       | Pred: vf47       | Char Acc: 3/4
# True: vecqb      | Pred: v2cqb      | Char Acc: 4/5
# True: vfsd9fyt   | Pred: vfsd9fyt   | Char Acc: 8/8
# True: vgiqt      | Pred: vgiql      | Char Acc: 4/5
# True: vgzy       | Pred: vgzy       | Char Acc: 4/4
# True: vhrnb      | Pred: jy4rne     | Char Acc: 0/5
# True: vi0d       | Pred: yiqd       | Char Acc: 2/4
# True: viv1ed3y   | Pred: v1v1ed3v   | Char Acc: 6/8
# True: vjcod9     | Pred: yj10o9     | Char Acc: 2/6
# True: vkfr       | Pred: vkfr       | Char Acc: 4/4
# True: vled8      | Pred: vled8      | Char Acc: 5/5
# True: vlsqa      | Pred: vlsqa      | Char Acc: 5/5
# True: vmubm06i   | Pred: mnbm06e    | Char Acc: 0/8
# True: vn2pai     | Pred: vn2pai     | Char Acc: 6/6
# True: vok5h26    | Pred: csr5z28    | Char Acc: 2/7
# True: vq2rlsh    | Pred: vq2rlsh    | Char Acc: 7/7
# True: vq3ft7f    | Pred: vq3fz77    | Char Acc: 5/7
# True: vqf8       | Pred: vqf3       | Char Acc: 3/4
# True: vr1n847a   | Pred: 4n1n847x   | Char Acc: 5/8
# True: vuei18     | Pred: vuei12     | Char Acc: 5/6
# True: vv4odhq6   | Pred: vv4cdhq6   | Char Acc: 7/8
# True: vvdmc      | Pred: vvdmc      | Char Acc: 5/5
# True: vvioeu     | Pred: vvi0eu     | Char Acc: 5/6
# True: vxtq4      | Pred: vxtqt      | Char Acc: 4/5
# True: vy4gui26   | Pred: vy4gui2f   | Char Acc: 7/8
# True: vyw3       | Pred: vyw3       | Char Acc: 4/4
# True: vyxo9      | Pred: vyxo7      | Char Acc: 4/5
# True: vyzexh     | Pred: vyzexh     | Char Acc: 6/6
# True: w0brzjyz   | Pred: w0brzjyz   | Char Acc: 8/8
# True: w14ekvmu   | Pred: w14ekvmu   | Char Acc: 8/8
# True: w15fnfz7   | Pred: w15fnfz7   | Char Acc: 8/8
# True: w1h7h3     | Pred: w1763      | Char Acc: 2/6
# True: w2s9       | Pred: w2s9       | Char Acc: 4/4
# True: w33ijj     | Pred: w3yijj     | Char Acc: 5/6
# True: w34gghin   | Pred: w34gghin   | Char Acc: 8/8
# True: w3dn       | Pred: w3dn       | Char Acc: 4/4
# True: w3rexsk    | Pred: u3newsx    | Char Acc: 3/7
# True: w3vgc      | Pred: w3vgc      | Char Acc: 5/5
# True: w4tabh     | Pred: w4ta8h     | Char Acc: 5/6
# True: w4yac      | Pred: wbyqo      | Char Acc: 2/5
# True: w58mucmx   | Pred: w58mucmx   | Char Acc: 8/8
# True: w5g0       | Pred: w520       | Char Acc: 3/4
# True: w62rj61a   | Pred: o62rj61o   | Char Acc: 6/8
# True: w6nxw1h    | Pred: w6nxw1h    | Char Acc: 7/7
# True: w6w78fr    | Pred: wgw78fn    | Char Acc: 5/7
# True: w72p       | Pred: w7p        | Char Acc: 2/4
# True: w76a       | Pred: w76a       | Char Acc: 4/4
# True: w7na       | Pred: uw7va      | Char Acc: 0/4
# True: w7txn88    | Pred: w7bxa88    | Char Acc: 5/7
# True: w867z      | Pred: w8672      | Char Acc: 4/5
# True: w8co       | Pred: w8co       | Char Acc: 4/4
# True: w8mv3xv    | Pred: w8mu3xv    | Char Acc: 6/7
# True: w8soc      | Pred: u8sec      | Char Acc: 3/5
# True: wa4k6      | Pred: na4k5      | Char Acc: 3/5
# True: wa7z       | Pred: wa7z       | Char Acc: 4/4
# True: was6kr6h   | Pred: was6ht6h   | Char Acc: 6/8
# True: wb609qj    | Pred: w8609qp    | Char Acc: 5/7
# True: wbbou83    | Pred: wyqqu03    | Char Acc: 3/7
# True: wbu9wu6    | Pred: wbu9wu6    | Char Acc: 7/7
# True: wcgxtu6    | Pred: ncgxlu6    | Char Acc: 5/7
# True: wchyh86    | Pred: wchyh86    | Char Acc: 7/7
# True: wcjoxp     | Pred: wcj0xp     | Char Acc: 5/6
# True: wcqsal     | Pred: vlasa1     | Char Acc: 2/6
# True: wcv2ys     | Pred: wcv2ys     | Char Acc: 6/6
# True: we9vdq     | Pred: wa9vdq     | Char Acc: 5/6
# True: wemep      | Pred: wemep      | Char Acc: 5/5
# True: wf8s6x     | Pred: wf8s6x     | Char Acc: 6/6
# True: wff13mpg   | Pred: wff13mpg   | Char Acc: 8/8
# True: wfs6q4ag   | Pred: wfdvqg     | Char Acc: 3/8
# True: wgow5      | Pred: wg0w5      | Char Acc: 4/5
# True: whgainm    | Pred: whgaiwh    | Char Acc: 5/7
# True: whs8wa     | Pred: whs8wa     | Char Acc: 6/6
# True: why8ub7r   | Pred: whu8ub7r   | Char Acc: 7/8
# True: wk80dulm   | Pred: x894da1a   | Char Acc: 1/8
# True: wkai       | Pred: mkat       | Char Acc: 2/4
# True: wkhbm      | Pred: wkn8m      | Char Acc: 3/5
# True: wkrp0ds    | Pred: whrn0ua    | Char Acc: 3/7
# True: wkvh       | Pred: wkuh       | Char Acc: 3/4
# True: wl09       | Pred: lul09      | Char Acc: 0/4
# True: wlt1oo     | Pred: wltiq0     | Char Acc: 3/6
# True: wm23u      | Pred: 4msy       | Char Acc: 1/5
# True: wmzfebyg   | Pred: wmzfebyg   | Char Acc: 8/8
# True: wnhjh      | Pred: mnhjh      | Char Acc: 4/5
# True: wnjl3z     | Pred: wnjl32     | Char Acc: 5/6
# True: wopik      | Pred: w0pik      | Char Acc: 4/5
# True: wpi8k4     | Pred: wpi8k1     | Char Acc: 5/6
# True: wpj2o      | Pred: u4j2e      | Char Acc: 2/5
# True: wpkvs6     | Pred: 4qvvs6     | Char Acc: 3/6
# True: wpm345     | Pred: wpm345     | Char Acc: 6/6
# True: wpuojf5f   | Pred: wpuqjp5p   | Char Acc: 5/8
# True: wq9b       | Pred: mq96       | Char Acc: 2/4
# True: wqgp7308   | Pred: w06p730g   | Char Acc: 5/8
# True: wqhw3c     | Pred: wqhw3c     | Char Acc: 6/6
# True: wqtt       | Pred: wqtt       | Char Acc: 4/4
# True: wrs4       | Pred: wtg4       | Char Acc: 2/4
# True: ws65i      | Pred: wbbi       | Char Acc: 1/5
# True: ws6w       | Pred: vs6w       | Char Acc: 3/4
# True: wspku      | Pred: wspku      | Char Acc: 5/5
# True: wu5lx      | Pred: wu5lx      | Char Acc: 5/5
# True: wupavqg8   | Pred: wupavqg8   | Char Acc: 8/8
# True: wv2lkwna   | Pred: wy2lwwmo   | Char Acc: 4/8
# True: wvefdi     | Pred: wvqpbs     | Char Acc: 2/6
# True: wvnwm      | Pred: wynww      | Char Acc: 3/5
# True: wwkhs2     | Pred: wwkhs2     | Char Acc: 6/6
# True: wwm1m      | Pred: uymim      | Char Acc: 2/5
# True: wwnvowv2   | Pred: unxvonv2   | Char Acc: 4/8
# True: wwoe2vi    | Pred: ww0e2vi    | Char Acc: 6/7
# True: wxw2g9o    | Pred: 4w239o     | Char Acc: 0/7
# True: wybb       | Pred: wybb       | Char Acc: 4/4
# True: wypj       | Pred: wyp3       | Char Acc: 3/4
# True: wz1l       | Pred: wzj1       | Char Acc: 2/4
# True: wzo7j      | Pred: wzo7j      | Char Acc: 5/5
# True: x1q3       | Pred: xzq3       | Char Acc: 3/4
# True: x2f7mwro   | Pred: x2f7mwro   | Char Acc: 8/8
# True: x2hj       | Pred: x2hi       | Char Acc: 3/4
# True: x2xk02p    | Pred: f2yxkd2p   | Char Acc: 1/7
# True: x31s3su    | Pred: v31s3su    | Char Acc: 6/7
# True: x46yxn7q   | Pred: h46yxn7q   | Char Acc: 7/8
# True: x4ou7j     | Pred: xdou0j     | Char Acc: 4/6
# True: x4qqf      | Pred: rzqyf      | Char Acc: 2/5
# True: x4t1       | Pred: k4ti       | Char Acc: 2/4
# True: x5jeo      | Pred: xsjeo      | Char Acc: 4/5
# True: x61t0z     | Pred: ra1f0z     | Char Acc: 3/6
# True: x6g6ybr    | Pred: x6g638r    | Char Acc: 5/7
# True: x6i6k      | Pred: x61mk      | Char Acc: 3/5
# True: x7mkdulu   | Pred: x7mkdu1v   | Char Acc: 6/8
# True: x88o0      | Pred: x880d      | Char Acc: 3/5
# True: x8ob9      | Pred: x808q      | Char Acc: 2/5
# True: x9rusb1    | Pred: x3fusb1    | Char Acc: 5/7
# True: xag8gf     | Pred: xag8gf     | Char Acc: 6/6
# True: xeoav      | Pred: xe0ay      | Char Acc: 3/5
# True: xfd22z6t   | Pred: xfd22z6t   | Char Acc: 8/8
# True: xfr1d0mj   | Pred: xeq10qmv   | Char Acc: 3/8
# True: xg4n0dgq   | Pred: xesm0dsq   | Char Acc: 4/8
# True: xgyfaku    | Pred: xgyfahu    | Char Acc: 6/7
# True: xhqxfi     | Pred: xhqxt1     | Char Acc: 4/6
# True: xjtj3l0    | Pred: xjtj310    | Char Acc: 6/7
# True: xk798xe    | Pred: xk798xe    | Char Acc: 7/7
# True: xl9a2fm    | Pred: xl9df7     | Char Acc: 3/7
# True: xlanpnt    | Pred: klanpat    | Char Acc: 5/7
# True: xmur       | Pred: jp         | Char Acc: 0/4
# True: xpelp8     | Pred: xpelp8     | Char Acc: 6/6
# True: xptpi      | Pred: xyjp1      | Char Acc: 2/5
# True: xr47ewz    | Pred: xr61exi    | Char Acc: 3/7
# True: xrgqo      | Pred: xrgqo      | Char Acc: 5/5
# True: xteqzb6    | Pred: xoeqz86    | Char Acc: 5/7
# True: xtzrp      | Pred: xtztp      | Char Acc: 4/5
# True: xuiiylwp   | Pred: hu1iylwp   | Char Acc: 6/8
# True: xun9       | Pred: xun9       | Char Acc: 4/4
# True: xupyep0m   | Pred: rpep0x     | Char Acc: 0/8
# True: xvho       | Pred: yyad       | Char Acc: 0/4
# True: xvowfg     | Pred: xv04fg     | Char Acc: 4/6
# True: xx8ncv     | Pred: h6dcu      | Char Acc: 0/6
# True: xxboh2p    | Pred: hk80w2p    | Char Acc: 2/7
# True: xxgu8su    | Pred: xxgu85u    | Char Acc: 6/7
# True: xxmao      | Pred: k2ao       | Char Acc: 0/5
# True: xze1h      | Pred: xze1h      | Char Acc: 5/5
# True: xzrf2      | Pred: xzif2      | Char Acc: 4/5
# True: y0jq       | Pred: yjq        | Char Acc: 1/4
# True: y1fto45    | Pred: y1ft04s    | Char Acc: 5/7
# True: y2meumjc   | Pred: qzqe0qfy   | Char Acc: 1/8
# True: y3ux06     | Pred: y3ux06     | Char Acc: 6/6
# True: y68r       | Pred: y68r       | Char Acc: 4/4
# True: y6ench2    | Pred: y6ewch2    | Char Acc: 6/7
# True: y6ttxt     | Pred: ygttxt     | Char Acc: 5/6
# True: y8rfhq6f   | Pred: q8rfhq6f   | Char Acc: 7/8
# True: y95u       | Pred: bj1hu      | Char Acc: 0/4
# True: yaakp      | Pred: yaakp      | Char Acc: 5/5
# True: yaavh21e   | Pred: yaavhz1e   | Char Acc: 7/8
# True: yc4w       | Pred: ygrj       | Char Acc: 1/4
# True: ycxb       | Pred: ycxb       | Char Acc: 4/4
# True: ydjf       | Pred: 7djf       | Char Acc: 3/4
# True: ydrtvf9    | Pred: 4datvf9    | Char Acc: 5/7
# True: ye3j8osm   | Pred: 4f9jq09m   | Char Acc: 2/8
# True: yeak       | Pred: yeak       | Char Acc: 4/4
# True: yf2u99j    | Pred: yf2u99j    | Char Acc: 7/7
# True: yfqf       | Pred: ydf        | Char Acc: 1/4
# True: ygdory15   | Pred: ygpopyz5   | Char Acc: 5/8
# True: ygpv7uq    | Pred: ygpv7ug    | Char Acc: 6/7
# True: yj4m       | Pred: yj4n       | Char Acc: 3/4
# True: yjhmfa     | Pred: yjmmfr     | Char Acc: 4/6
# True: yjzvdy     | Pred: yjzvdy     | Char Acc: 6/6
# True: yk9twdv    | Pred: yk9twdv    | Char Acc: 7/7
# True: ykhc0      | Pred: ykhci      | Char Acc: 4/5
# True: ylk9pbpy   | Pred: yih9pbpy   | Char Acc: 6/8
# True: yn7g85     | Pred: yn7g85     | Char Acc: 6/6
# True: yogyk      | Pred: y0gyk      | Char Acc: 4/5
# True: yox16c9    | Pred: ydx18c9    | Char Acc: 5/7
# True: yp1ye570   | Pred: 9hjye578   | Char Acc: 4/8
# True: yp838obs   | Pred: yp8i8obs   | Char Acc: 7/8
# True: yrrc       | Pred: vftc       | Char Acc: 1/4
# True: ys0167     | Pred: ys0167     | Char Acc: 6/6
# True: yslwm6mb   | Pred: y5lwm6mb   | Char Acc: 7/8
# True: ysy3b      | Pred: isys8      | Char Acc: 2/5
# True: yu7y2spi   | Pred: yu7y2spi   | Char Acc: 8/8
# True: yweo       | Pred: 3we0       | Char Acc: 2/4
# True: yxnby      | Pred: 4anby      | Char Acc: 3/5
# True: yxoc6      | Pred: yxacf      | Char Acc: 3/5
# True: yyqt6      | Pred: yywc6      | Char Acc: 3/5
# True: yzjnx5d    | Pred: yzjnx5d    | Char Acc: 7/7
# True: z0b8tc     | Pred: 70581c     | Char Acc: 3/6
# True: z1gxiila   | Pred: z1gxiil4   | Char Acc: 7/8
# True: z1stkhmn   | Pred: zistknp    | Char Acc: 4/8
# True: z254       | Pred: z2s4       | Char Acc: 3/4
# True: z2cl9      | Pred: z2cl9      | Char Acc: 5/5
# True: z2m7       | Pred: z2m7       | Char Acc: 4/4
# True: z3e7z0     | Pred: z3e7z0     | Char Acc: 6/6
# True: z3n0pput   | Pred: 3nq7put    | Char Acc: 1/8
# True: z599xbz    | Pred: z699xb2    | Char Acc: 5/7
# True: z5bbtky3   | Pred: 2sbbtky3   | Char Acc: 6/8
# True: z5bm2      | Pred: ze9zi      | Char Acc: 1/5
# True: z5k4       | Pred: z5k4       | Char Acc: 4/4
# True: z5oi       | Pred: z50i       | Char Acc: 3/4
# True: z63qv      | Pred: zqv        | Char Acc: 1/5
# True: z6r0       | Pred: z6r0       | Char Acc: 4/4
# True: z7vq       | Pred: 17mq       | Char Acc: 2/4
# True: z90sk98    | Pred: z90sk98    | Char Acc: 7/7
# True: z9b8bq0y   | Pred: 29bgbq0y   | Char Acc: 6/8
# True: zafym      | Pred: zafym      | Char Acc: 5/5
# True: zb7nus     | Pred: z87nus     | Char Acc: 5/6
# True: zbbm       | Pred: zbbm       | Char Acc: 4/4
# True: zbe1       | Pred: 22e1       | Char Acc: 2/4
# True: zbk1c      | Pred: zbk1d      | Char Acc: 4/5
# True: zcn0       | Pred: zcmo       | Char Acc: 2/4
# True: zddt       | Pred: zddt       | Char Acc: 4/4
# True: zdoblf     | Pred: zd08lf     | Char Acc: 4/6
# True: zeivut8    | Pred: ce1vute    | Char Acc: 4/7
# True: zek18ad0   | Pred: zsh18ad0   | Char Acc: 6/8
# True: zfqd1d     | Pred: ziqa1d     | Char Acc: 4/6
# True: zjalw      | Pred: zjalw      | Char Acc: 5/5
# True: zjh8v      | Pred: zjh8v      | Char Acc: 5/5
# True: zji3       | Pred: 23i3       | Char Acc: 2/4
# True: zkw5       | Pred: zkw5       | Char Acc: 4/4
# True: zlje       | Pred: zlye       | Char Acc: 3/4
# True: zm17tr8    | Pred: z4i3tr     | Char Acc: 3/7
# True: zmnaw8vx   | Pred: 4mqawq4t   | Char Acc: 3/8
# True: zn19       | Pred: zn19       | Char Acc: 4/4
# True: zngqboe9   | Pred: angq80e9   | Char Acc: 5/8
# True: zp29       | Pred: 2p29       | Char Acc: 3/4
# True: zqdfto     | Pred: eqcd6a     | Char Acc: 1/6
# True: zrfa0m0j   | Pred: zkfaumdj   | Char Acc: 5/8
# True: zsauik50   | Pred: z9au1x50   | Char Acc: 5/8
# True: zsjflk     | Pred: zsjflk     | Char Acc: 6/6
# True: zswopu     | Pred: z9w0pu     | Char Acc: 4/6
# True: zszdczic   | Pred: zszdczic   | Char Acc: 8/8
# True: zu5zt      | Pred: zu5zt      | Char Acc: 5/5
# True: zumj       | Pred: zumj       | Char Acc: 4/4
# True: zv4bz0n    | Pred: zv4bz0n    | Char Acc: 7/7
# True: zwc9imu    | Pred: zwc9imu    | Char Acc: 7/7
# True: zwjhgwvj   | Pred: zwjhgwvl   | Char Acc: 7/8
# True: zwya13o    | Pred: zwya13o    | Char Acc: 7/7
# True: zxhi2v8    | Pred: zxhi2v8    | Char Acc: 7/7
# True: zxqlq      | Pred: zxqlq      | Char Acc: 5/5
# True: zzs5bg     | Pred: zzs5ug     | Char Acc: 5/6
# True: zztd6      | Pred: zztdg      | Char Acc: 4/5
# Word Accuracy: 28.00%
# Character Accuracy: 70.67%
